# %%
import os
import glob
import cv2
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms
from torch.nn.functional import interpolate

# %%
import torch.nn.functional as F
import math


class CAM(nn.Module):
    def __init__(self, channels, r=16):
        super(CAM, self).__init__()
        self.channels = channels
        self.r = r
        self.mlp = nn.Sequential(
            nn.Linear(channels, channels // r, bias=True),
            nn.ReLU(inplace=True),
            nn.Linear(channels // r, channels, bias=True)
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        max_pool = F.adaptive_max_pool2d(x, (1, 1)).view(b, c)
        avg_pool = F.adaptive_avg_pool2d(x, (1, 1)).view(b, c)

        max_out = self.mlp(max_pool).view(b, c, 1, 1)
        avg_out = self.mlp(avg_pool).view(b, c, 1, 1)

        attention = torch.sigmoid(max_out + avg_out)
        return x * attention


class SAM(nn.Module):
    def __init__(self):
        super(SAM, self).__init__()
        self.conv = nn.Conv2d(2, 1, kernel_size=7, stride=1, padding=3, bias=False)

    def forward(self, x):
        max_pool = torch.max(x, dim=1, keepdim=True)[0]
        avg_pool = torch.mean(x, dim=1, keepdim=True)
        attention = self.conv(torch.cat([max_pool, avg_pool], dim=1))
        return x * torch.sigmoid(attention)


class CBAM(nn.Module):
    def __init__(self, channels, r=16):
        super(CBAM, self).__init__()
        self.cam = CAM(channels, r)
        self.sam = SAM()

    def forward(self, x):
        x = self.cam(x)
        x = self.sam(x)
        return x


class DoubleConv(nn.Module):
    """ [(Conv2d) => (BN) => (ReLU)] * 2 + CBAM + Dropout """

    def __init__(self, in_channels, out_channels) -> None:
        super().__init__()

        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),

            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

        self.cbam = CBAM(out_channels)

        self.dropout = nn.Dropout2d(p=0.3)

        self.residual = nn.Conv2d(in_channels, out_channels, kernel_size=1) \
            if in_channels != out_channels else nn.Identity()

    def forward(self, x):
        identity = self.residual(x)
        x = self.double_conv(x)
        x = self.cbam(x)
        x = self.dropout(x)
        return x + identity  



class DownSample(nn.Module):
    """ MaxPool => DoubleConv """
    def __init__(self,in_channels,out_channels) -> None:
        super().__init__()
        self.down_sample = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels,out_channels)
        )
    def forward(self,x):
        x  = self.down_sample(x)
        return x



class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return self.conv(x)



class UpSample(nn.Module):
    def __init__(self,in_channels,out_channels,c:int) -> None:
        """ UpSample input tensor by a factor of `c`
                - the value of base 2 log c defines the number of upsample
                layers that will be applied
        """
        super().__init__()
        n = 0 if c == 0 else int(math.log(c,2))

        self.upsample = nn.ModuleList(
            [nn.ConvTranspose2d(in_channels,in_channels,2,2) for i in range(n)]
        )
        self.conv_3 = nn.Conv2d(in_channels,out_channels,3,padding="same",stride=1)

    def forward(self,x):
        for layer in self.upsample:
            x = layer(x)
        return self.conv_3(x)

class UpSample2(nn.Module):
    def __init__(self,in_channels,out_channels,c:int) -> None:
        """ UpSample input tensor by a factor of `c`
                - the value of base 2 log c defines the number of upsample
                layers that will be applied
        """
        super().__init__()
        n = 0 if c == 0 else int(math.log(c,2))
        #print(f'LOG OF C:  {int(math.log(c,2))}')

        self.upsample = nn.ModuleList(
            [nn.ConvTranspose2d(in_channels,in_channels,2,2) for i in range(n)]
        )
        self.conv_3 = nn.Conv2d(in_channels,out_channels,3,padding="same",stride=1)

    def forward(self,x):
        for layer in self.upsample:
            #print(f'BEFORE UPSAMPEL: {x.shape}')
            x = layer(x)
            #print(f'After Transpose2D: {x.shape}')
            x = self.conv_3(x)
            #print(f'After Conv2D: {x.shape}')
        return x#self.conv_3(x)

class UNet(nn.Module):
    def __init__(self, in_channels, out_channels, n: int = 8) -> None:
        """
        Construct the J-net model.
        Args:
            in_channels: The number of color channels of the input image. 0:for binary 3: for RGB
            out_channels: The number of color channels of the input mask, corresponds to the number
                            of classes.Includes the background
            n: Channels size of the first CNN in the encoder layer. The bigger this value the bigger
                the number of parameters of the model. Defaults to n = 8, which is recommended by the
                authors of the paper.
        """
        super().__init__()
        # ------ Input convolution --------------
        self.in_conv = DoubleConv(in_channels, n)
        # -------- Encoder ----------------------
        self.down_1 = DownSample(n, 2 * n)
        self.down_2 = DownSample(2 * n, 4 * n)
        self.down_3 = DownSample(4 * n, 8 * n)
        self.down_4 = DownSample(8 * n, 16 * n)
        

        # -------- Upsampling ------------------ias=Tru
        self.up_1024_512 = UpSample(16 * n, 8 * n, 2)

        self.up_512_64 = UpSample(8 * n, n, 8)
        
        #self.up_512_64_more = UpSample(8 * n, n, 16)
        
        
        self.up_512_128 = UpSample(8 * n, 2 * n, 4)
        self.up_512_256 = UpSample(8 * n, 4 * n, 2)
        self.up_512_512 = UpSample(8 * n, 8 * n, 0)

        self.up_256_64 = UpSample(4 * n, n, 4)
        #self.up_256_64_more = UpSample(4 * n, n, 8)
        self.up_256_128 = UpSample(4 * n, 2 * n, 2)
        self.up_256_256 = UpSample(4 * n, 4 * n, 0)

        self.up_128_64 = UpSample(2 * n, n, 2)
        #self.up_128_64_more = UpSample(2 * n, n, 4)
        self.up_128_128 = UpSample(2 * n, 2 * n, 0)

        self.up_64_64 = UpSample(n, n, 0)
        m = int(n *0.5)
        
        self.up_64_32 =  UpSample2(out_channels, out_channels, 2)
        self.up_16_64 = UpSample(out_channels, out_channels, 2)
        
  
        self.up_skip_8 =  UpSample2(out_channels, out_channels, 8)
        self.up_skip_4 =  UpSample2(out_channels, out_channels, 4)
        
        
        self.up_concat =  UpSample2(2*out_channels, out_channels, 2)

        # ------ Decoder block ---------------
        self.dec_4 = DoubleConv(2 * 8 * n, 8 * n)
        self.dec_3 = DoubleConv(3 * 4 * n, 4 * n)
        self.dec_2 = DoubleConv(4 * 2 * n, 2 * n)
        self.dec_1 = DoubleConv(5 * n, n )
         # ------ Output convolution

        self.out_conv = OutConv(n, out_channels)
        
        

    def forward(self, x):
        x = self.in_conv(x)  # 64
        # ---- Encoder outputs
        x_enc_1 = self.down_1(x)  # 128
        x_enc_2 = self.down_2(x_enc_1)  # 256
        x_enc_3 = self.down_3(x_enc_2)  # 512
        x_enc_4 = self.down_4(x_enc_3)  # 1024

        # ------ decoder outputs
        x_up_1 = self.up_1024_512(x_enc_4)
        x_dec_4 = self.dec_4(torch.cat([x_up_1, self.up_512_512(x_enc_3)], dim=1))

        x_up_2 = self.up_512_256(x_dec_4)
        x_dec_3 = self.dec_3(torch.cat([x_up_2,
                                        self.up_512_256(x_enc_3),
                                        self.up_256_256(x_enc_2)
                                        ],
                                       dim=1))

        x_up_3 = self.up_256_128(x_dec_3)
        x_dec_2 = self.dec_2(torch.cat([
            x_up_3,
            self.up_512_128(x_enc_3),
            self.up_256_128(x_enc_2),
            self.up_128_128(x_enc_1)
        ], dim=1))

        x_up_4 = self.up_128_64(x_dec_2)
        x_dec_1 = self.dec_1(torch.cat([
            x_up_4,
            self.up_512_64(x_enc_3),
            self.up_256_64(x_enc_2),
            self.up_128_64(x_enc_1),
            self.up_64_64(x)
        ], dim=1))

        out1 =  self.out_conv(x_dec_1) # 16 / 32 / 80
        
        out2 = self.up_64_32(out1) # 32   / 64 / 160
        out3 = self.up_16_64(out2) # 64   / 128 / 320
        
        
        
        
        out1_skip_4 = self.up_skip_4(out1)      
        out1_skip_8 = self.up_skip_8(out1)  
        

        out4 = self.up_concat(torch.cat([out1_skip_4,out3],dim=1))
        out5 = self.up_concat(torch.cat([out1_skip_8,out4],dim=1))
        
       

        return out1, out2, out3, out4, out5
        
def save_net(ckpt_dir, net, optim, epoch):
    os.makedirs(ckpt_dir, exist_ok=True)
    path = os.path.join(ckpt_dir, f'model_epoch_{epoch}.pth')
    torch.save({'epoch': epoch, 'model': net.state_dict(), 'optim': optim.state_dict()}, path)

def load_net(ckpt_dir, net, optim):
    if not os.path.exists(ckpt_dir): return net, optim, 0
    files = sorted(glob.glob(os.path.join(ckpt_dir, '*.pth')))
    if not files: return net, optim, 0
    checkpoint = torch.load(files[-1])
    net.load_state_dict(checkpoint['model'])
    optim.load_state_dict(checkpoint['optim'])
    return net, optim, checkpoint['epoch'] + 1

# %%
import os
import glob
import cv2
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import random

# === Paths and Config ===
ROOT_DIR = "/kaggle/working"
DATA_DIR = os.path.join(ROOT_DIR, 'prostate_data')
CKPT_DIR = os.path.join(ROOT_DIR, 'checkpoints_jnet_16')
LOG_DIR = os.path.join(ROOT_DIR, 'logs')
IMGS_DIR = os.path.join(DATA_DIR, 'imgs_r')
LABELS_DIR = os.path.join(DATA_DIR, 'labels')

# === Create directories ===
for path in [
    CKPT_DIR, LOG_DIR, os.path.join(LOG_DIR, 'train'), os.path.join(LOG_DIR, 'val'),
    os.path.join(IMGS_DIR, 'train'), os.path.join(IMGS_DIR, 'val'), os.path.join(IMGS_DIR, 'test'),
    os.path.join(LABELS_DIR, 'train'), os.path.join(LABELS_DIR, 'val'), os.path.join(LABELS_DIR, 'test')
]:
    os.makedirs(path, exist_ok=True)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# === Config ===
class Config:
    LEARNING_RATE = 1e-3
    BATCH_SIZE = 64
    NUM_EPOCHS = 100
    L1_LAMBDA = 1e-5
    L2_LAMBDA = 1e-5
    IOU_LAMBDA = 1.0
    DICE_LAMBDA = 1.0

cfg = Config()

# === Dataset ===
class CustomDataset(Dataset):
    def __init__(self, imgs_dir, labels_dir, transform=None):
        self.imgs = sorted(glob.glob(os.path.join(imgs_dir, '*.jpg')))
        self.labels = sorted(glob.glob(os.path.join(labels_dir, '*.jpg')))
        self.transform = transform

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, index):
        # Load RGB image
        img = cv2.imread(self.imgs[index], cv2.IMREAD_COLOR) / 255.0  # shape: (H, W, 3)
        
        # Load label as grayscale binary mask
        label = cv2.imread(self.labels[index], cv2.IMREAD_GRAYSCALE) / 255.0  # shape: (H, W)

        # Resize for deep supervision
        img_d = cv2.resize(img, (16, 16), interpolation=cv2.INTER_NEAREST)
        label_d = cv2.resize(label, (16, 16), interpolation=cv2.INTER_NEAREST)

        # Resize main
        img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_NEAREST)
        label = cv2.resize(label, (256, 256), interpolation=cv2.INTER_NEAREST)

        sample = {
            'img': img,
            'label': label[:, :, np.newaxis],  # add channel dim
            'img_d': img_d,
            'label_d': label_d[:, :, np.newaxis],
            'id': os.path.basename(self.imgs[index])[:-4]
        }

        if self.transform:
            sample = self.transform(sample)

        return sample

# === Transforms ===
class ToTensor:
    def __call__(self, data):
        for k in ['img', 'img_d']:
            data[k] = torch.tensor(data[k].transpose(2, 0, 1), dtype=torch.float32)
        for k in ['label', 'label_d']:
            data[k] = torch.tensor(data[k].transpose(2, 0, 1), dtype=torch.float32)
        return data

class RandomFlip:
    def __call__(self, data):
        if np.random.rand() > 0.5:
            for k in ['img', 'label', 'img_d', 'label_d']:
                data[k] = np.flip(data[k], axis=1).copy()
        if np.random.rand() > 0.5:
            for k in ['img', 'label', 'img_d', 'label_d']:
                data[k] = np.flip(data[k], axis=0).copy()
        return data

class RandomRotate:
    def __call__(self, data):
        angle = random.choice([0, 90, 180, 270])
        for k in ['img', 'label', 'img_d', 'label_d']:
            data[k] = np.rot90(data[k], k=angle // 90).copy()
        return data

class RandomBrightness:
    def __call__(self, data):
        factor = 0.8 + np.random.uniform(0, 0.4)  # Between 0.8 and 1.2
        data['img'] = np.clip(data['img'] * factor, 0, 1)
        data['img_d'] = np.clip(data['img_d'] * factor, 0, 1)
        return data

class AddGaussianNoise:
    def __call__(self, data):
        noise = np.random.normal(0, 0.02, data['img'].shape)
        data['img'] = np.clip(data['img'] + noise, 0, 1)
        
        noise_d = np.random.normal(0, 0.02, data['img_d'].shape)
        data['img_d'] = np.clip(data['img_d'] + noise_d, 0, 1)
        return data


train_transform = transforms.Compose([
    RandomFlip(),
    RandomRotate(),
    RandomBrightness(),
    AddGaussianNoise(),
    ToTensor()
])

val_transform = transforms.Compose([
    ToTensor()
])

# === Loaders ===
train_set = CustomDataset(
    imgs_dir="/kaggle/input/kasvir-svg-train-val/train/images",
    labels_dir="/kaggle/input/kasvir-svg-train-val/train/masks",
    transform=train_transform
)

val_set = CustomDataset(
    imgs_dir="/kaggle/input/kasvir-svg-train-val/val/images",
    labels_dir="/kaggle/input/kasvir-svg-train-val/val/masks",
    transform=val_transform
)

train_loader = DataLoader(train_set, batch_size=cfg.BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set, batch_size=cfg.BATCH_SIZE)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import os
import numpy as np

# === Dice Loss & Score ===
def dice_loss(pred, target, smooth=1e-6):
    pred = torch.sigmoid(pred)
    intersection = (pred * target).sum(dim=(1, 2, 3))
    dice = (2. * intersection + smooth) / (pred.sum(dim=(1, 2, 3)) + target.sum(dim=(1, 2, 3)) + smooth)
    return 1 - dice.mean()

def dice_score(pred, target, smooth=1e-6):
    pred = (torch.sigmoid(pred) > 0.5).float()
    intersection = (pred * target).sum(dim=(1, 2, 3))
    score = (2. * intersection + smooth) / (pred.sum(dim=(1, 2, 3)) + target.sum(dim=(1, 2, 3)) + smooth)
    return score.mean().item()

# === IoU Loss & Score ===
def iou_loss(pred, target, smooth=1e-6):
    pred = torch.sigmoid(pred)
    intersection = (pred * target).sum(dim=(1, 2, 3))
    union = (pred + target - pred * target).sum(dim=(1, 2, 3))
    iou = (intersection + smooth) / (union + smooth)
    return 1 - iou.mean()

def iou_score(pred, target, smooth=1e-6):
    pred = (torch.sigmoid(pred) > 0.5).float()
    intersection = (pred * target).sum(dim=(1, 2, 3))
    union = (pred + target - pred * target).sum(dim=(1, 2, 3))
    return ((intersection + smooth) / (union + smooth)).mean().item()

# === Model, Loss, Optimizer ===
net = UNet(3, 1, 64).to(device)
loss_fn = nn.BCEWithLogitsLoss().to(device)
optim = torch.optim.Adam(net.parameters(), lr=cfg.LEARNING_RATE)  # L2 regularization removed

train_writer = SummaryWriter(os.path.join(LOG_DIR, 'train'))
val_writer = SummaryWriter(os.path.join(LOG_DIR, 'val'))
start_epoch = 0

# === Training Loop ===
for epoch in range(start_epoch, cfg.NUM_EPOCHS):
    net.train()
    train_losses, bce_losses, dice_losses, iou_losses = [], [], [], []
    dice_scores, iou_scores = [], []

    for batch in train_loader:
        img = batch['img_d'].to(device)
        label = batch['label'].to(device)
        label_d = batch['label_d'].to(device)

        output1, output2, output3, output4, output5 = net(img)

        resized = [
            F.interpolate(label, size=(32, 32), mode='bilinear', align_corners=False),
            F.interpolate(label, size=(64, 64), mode='bilinear', align_corners=False),
            F.interpolate(label, size=(128, 128), mode='bilinear', align_corners=False)
        ]

        # === Losses ===
        bce_loss = (
            loss_fn(output1, label_d) +
            loss_fn(output2, resized[0]) +
            loss_fn(output3, resized[1]) +
            loss_fn(output4, resized[2]) +
            loss_fn(output5, label)
        )

        dice = dice_loss(output5, label)
        iou = iou_loss(output5, label)

        # Total Loss (without L1 and L2 regularization)
        loss = bce_loss + cfg.DICE_LAMBDA * dice + cfg.IOU_LAMBDA * iou

        # Backward
        optim.zero_grad()
        loss.backward()
        optim.step()

        # === Logging individual losses ===
        train_losses.append(loss.item())
        bce_losses.append(bce_loss.item())
        dice_losses.append(dice.item())
        iou_losses.append(iou.item())
        dice_scores.append(1 - dice.item())
        iou_scores.append(1 - iou.item())

        print(f'[Train] Epoch {epoch}/{cfg.NUM_EPOCHS} | Total: {loss.item():.4f} | BCE: {bce_loss.item():.4f} | Dice: {1 - dice.item():.4f} | IoU: {1 - iou.item():.4f}')

    # === TensorBoard Logging ===
    train_writer.add_scalar('train/total_loss', np.mean(train_losses), epoch)
    train_writer.add_scalar('train/bce_loss', np.mean(bce_losses), epoch)
    train_writer.add_scalar('train/dice_loss', np.mean(dice_losses), epoch)
    train_writer.add_scalar('train/iou_loss', np.mean(iou_losses), epoch)
    train_writer.add_scalar('train/dice_score', np.mean(dice_scores), epoch)
    train_writer.add_scalar('train/iou_score', np.mean(iou_scores), epoch)

    # === Validation ===
    net.eval()
    val_losses, val_dice_scores, val_iou_scores = [], [], []

    with torch.no_grad():
        for batch in val_loader:
            img = batch['img_d'].to(device)
            label = batch['label'].to(device)
            id_list = batch['id']

            outputs = net(img)
            output_final = outputs[-1]
            val_loss = loss_fn(output_final, label)

            val_losses.append(val_loss.item())
            val_dice_scores.append(dice_score(output_final, label))
            val_iou_scores.append(iou_score(output_final, label))

            if epoch == cfg.NUM_EPOCHS - 1:
                os.makedirs('./pred_out/', exist_ok=True)
                for i, id in enumerate(id_list):
                    np.save(f'./pred_out/{id}.npy', output_final[i].cpu().numpy())

            print(f'[Val] Epoch {epoch} | BCE Loss: {val_loss.item():.4f} | Dice: {val_dice_scores[-1]:.4f} | IoU: {val_iou_scores[-1]:.4f}')

    val_writer.add_scalar('val/bce_loss', np.mean(val_losses), epoch)
    val_writer.add_scalar('val/dice_score', np.mean(val_dice_scores), epoch)
    val_writer.add_scalar('val/iou_score', np.mean(val_iou_scores), epoch)

    # === Summary ===
    print(f'==> Epoch {epoch}')
    print(f'    Train Total Loss : {np.mean(train_losses):.4f} | BCE: {np.mean(bce_losses):.4f} | Dice score: {np.mean(dice_scores):.4f} | IoU score: {np.mean(iou_scores):.4f}')
    print(f'    Val   BCE Loss   : {np.mean(val_losses):.4f} | Dice score: {np.mean(val_dice_scores):.4f} | IoU score : {np.mean(val_iou_scores):.4f}')

    if epoch % 5 == 0 or epoch in {1, 4}:
        save_net(CKPT_DIR, net, optim, epoch)

train_writer.close()
val_writer.close()
# Out:
# [Train] Epoch 0/100 | Total: 4.9226 | BCE: 3.2209 | Dice: 0.1892 | IoU: 0.1091
# [Train] Epoch 0/100 | Total: 4.7828 | BCE: 3.0944 | Dice: 0.1969 | IoU: 0.1147
# [Train] Epoch 0/100 | Total: 4.6456 | BCE: 2.9849 | Dice: 0.2147 | IoU: 0.1246
# [Train] Epoch 0/100 | Total: 4.9716 | BCE: 3.3010 | Dice: 0.2071 | IoU: 0.1222
# [Train] Epoch 0/100 | Total: 4.5983 | BCE: 2.9249 | Dice: 0.2069 | IoU: 0.1197
# [Train] Epoch 0/100 | Total: 4.6100 | BCE: 2.9317 | Dice: 0.2027 | IoU: 0.1189
# [Train] Epoch 0/100 | Total: 4.6095 | BCE: 2.9190 | Dice: 0.1955 | IoU: 0.1140
# [Train] Epoch 0/100 | Total: 4.5811 | BCE: 2.8940 | Dice: 0.1983 | IoU: 0.1146
# [Train] Epoch 0/100 | Total: 4.5475 | BCE: 2.8501 | Dice: 0.1920 | IoU: 0.1106
# [Train] Epoch 0/100 | Total: 4.5167 | BCE: 2.7955 | Dice: 0.1775 | IoU: 0.1012
# [Train] Epoch 0/100 | Total: 4.5576 | BCE: 2.9002 | Dice: 0.2161 | IoU: 0.1265
# [Train] Epoch 0/100 | Total: 4.5431 | BCE: 2.8751 | Dice: 0.2100 | IoU: 0.1221
# [Train] Epoch 0/100 | Total: 4.4742 | BCE: 2.7678 | Dice: 0.1875 | IoU: 0.1061
# [Val] Epoch 0 | BCE Loss: 0.5696 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 0 | BCE Loss: 0.5713 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 0 | BCE Loss: 0.5900 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 0 | BCE Loss: 0.5544 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 0
#     Train Total Loss : 4.6431 | BCE: 2.9584 | Dice score: 0.1996 | IoU score: 0.1157
#     Val   BCE Loss   : 0.5713 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 1/100 | Total: 4.4600 | BCE: 2.7255 | Dice: 0.1694 | IoU: 0.0961
# [Train] Epoch 1/100 | Total: 4.4898 | BCE: 2.7756 | Dice: 0.1815 | IoU: 0.1044
# [Train] Epoch 1/100 | Total: 4.4844 | BCE: 2.8035 | Dice: 0.2024 | IoU: 0.1168
# [Train] Epoch 1/100 | Total: 4.4899 | BCE: 2.7745 | Dice: 0.1812 | IoU: 0.1035
# [Train] Epoch 1/100 | Total: 4.4398 | BCE: 2.7590 | Dice: 0.2030 | IoU: 0.1163
# [Train] Epoch 1/100 | Total: 4.4878 | BCE: 2.8019 | Dice: 0.1988 | IoU: 0.1153
# [Train] Epoch 1/100 | Total: 4.4277 | BCE: 2.7064 | Dice: 0.1775 | IoU: 0.1012
# [Train] Epoch 1/100 | Total: 4.4947 | BCE: 2.8533 | Dice: 0.2258 | IoU: 0.1328
# [Train] Epoch 1/100 | Total: 4.4247 | BCE: 2.7244 | Dice: 0.1906 | IoU: 0.1092
# [Train] Epoch 1/100 | Total: 4.5065 | BCE: 2.8717 | Dice: 0.2295 | IoU: 0.1356
# [Train] Epoch 1/100 | Total: 4.4504 | BCE: 2.7715 | Dice: 0.2029 | IoU: 0.1182
# [Train] Epoch 1/100 | Total: 4.4081 | BCE: 2.7135 | Dice: 0.1937 | IoU: 0.1117
# [Train] Epoch 1/100 | Total: 4.4201 | BCE: 2.7101 | Dice: 0.1846 | IoU: 0.1055
# [Val] Epoch 1 | BCE Loss: 0.5397 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 1 | BCE Loss: 0.5419 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 1 | BCE Loss: 0.5662 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 1 | BCE Loss: 0.5198 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 1
#     Train Total Loss : 4.4603 | BCE: 2.7685 | Dice score: 0.1954 | IoU score: 0.1128
#     Val   BCE Loss   : 0.5419 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 2/100 | Total: 4.3778 | BCE: 2.6687 | Dice: 0.1853 | IoU: 0.1057
# [Train] Epoch 2/100 | Total: 4.3689 | BCE: 2.6524 | Dice: 0.1810 | IoU: 0.1025
# [Train] Epoch 2/100 | Total: 4.3725 | BCE: 2.6521 | Dice: 0.1783 | IoU: 0.1013
# [Train] Epoch 2/100 | Total: 4.3810 | BCE: 2.6636 | Dice: 0.1798 | IoU: 0.1028
# [Train] Epoch 2/100 | Total: 4.3550 | BCE: 2.6560 | Dice: 0.1913 | IoU: 0.1097
# [Train] Epoch 2/100 | Total: 4.4021 | BCE: 2.7040 | Dice: 0.1909 | IoU: 0.1109
# [Train] Epoch 2/100 | Total: 4.3787 | BCE: 2.6775 | Dice: 0.1896 | IoU: 0.1092
# [Train] Epoch 2/100 | Total: 4.3777 | BCE: 2.6906 | Dice: 0.1984 | IoU: 0.1145
# [Train] Epoch 2/100 | Total: 4.3258 | BCE: 2.6199 | Dice: 0.1869 | IoU: 0.1071
# [Train] Epoch 2/100 | Total: 4.3458 | BCE: 2.6547 | Dice: 0.1960 | IoU: 0.1129
# [Train] Epoch 2/100 | Total: 4.3065 | BCE: 2.6087 | Dice: 0.1925 | IoU: 0.1098
# [Train] Epoch 2/100 | Total: 4.3657 | BCE: 2.7079 | Dice: 0.2164 | IoU: 0.1258
# [Train] Epoch 2/100 | Total: 4.3178 | BCE: 2.6104 | Dice: 0.1861 | IoU: 0.1064
# [Val] Epoch 2 | BCE Loss: 0.5059 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 2 | BCE Loss: 0.5088 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 2 | BCE Loss: 0.5404 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 2 | BCE Loss: 0.4802 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 2
#     Train Total Loss : 4.3596 | BCE: 2.6590 | Dice score: 0.1902 | IoU score: 0.1091
#     Val   BCE Loss   : 0.5088 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 3/100 | Total: 4.2788 | BCE: 2.5867 | Dice: 0.1961 | IoU: 0.1119
# [Train] Epoch 3/100 | Total: 4.2925 | BCE: 2.5795 | Dice: 0.1828 | IoU: 0.1042
# [Train] Epoch 3/100 | Total: 4.2502 | BCE: 2.5077 | Dice: 0.1644 | IoU: 0.0931
# [Train] Epoch 3/100 | Total: 4.2603 | BCE: 2.5510 | Dice: 0.1852 | IoU: 0.1055
# [Train] Epoch 3/100 | Total: 4.2047 | BCE: 2.4635 | Dice: 0.1656 | IoU: 0.0932
# [Train] Epoch 3/100 | Total: 4.2843 | BCE: 2.5856 | Dice: 0.1918 | IoU: 0.1095
# [Train] Epoch 3/100 | Total: 4.3769 | BCE: 2.6991 | Dice: 0.2039 | IoU: 0.1183
# [Train] Epoch 3/100 | Total: 4.2762 | BCE: 2.5482 | Dice: 0.1736 | IoU: 0.0984
# [Train] Epoch 3/100 | Total: 4.2508 | BCE: 2.5410 | Dice: 0.1851 | IoU: 0.1051
# [Train] Epoch 3/100 | Total: 4.2349 | BCE: 2.5137 | Dice: 0.1777 | IoU: 0.1011
# [Train] Epoch 3/100 | Total: 4.1822 | BCE: 2.4630 | Dice: 0.1794 | IoU: 0.1014
# [Train] Epoch 3/100 | Total: 4.2432 | BCE: 2.5479 | Dice: 0.1941 | IoU: 0.1106
# [Train] Epoch 3/100 | Total: 4.2782 | BCE: 2.5544 | Dice: 0.1758 | IoU: 0.1004
# [Val] Epoch 3 | BCE Loss: 0.4701 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 3 | BCE Loss: 0.4738 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 3 | BCE Loss: 0.5147 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 3 | BCE Loss: 0.4369 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 3
#     Train Total Loss : 4.2626 | BCE: 2.5493 | Dice score: 0.1827 | IoU score: 0.1040
#     Val   BCE Loss   : 0.4739 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 4/100 | Total: 4.1681 | BCE: 2.4627 | Dice: 0.1883 | IoU: 0.1063
# [Train] Epoch 4/100 | Total: 4.1503 | BCE: 2.4245 | Dice: 0.1754 | IoU: 0.0988
# [Train] Epoch 4/100 | Total: 4.0943 | BCE: 2.3331 | Dice: 0.1531 | IoU: 0.0857
# [Train] Epoch 4/100 | Total: 4.1925 | BCE: 2.4543 | Dice: 0.1674 | IoU: 0.0945
# [Train] Epoch 4/100 | Total: 4.1767 | BCE: 2.4592 | Dice: 0.1804 | IoU: 0.1022
# [Train] Epoch 4/100 | Total: 4.1182 | BCE: 2.4050 | Dice: 0.1835 | IoU: 0.1032
# [Train] Epoch 4/100 | Total: 4.2347 | BCE: 2.5314 | Dice: 0.1889 | IoU: 0.1078
# [Train] Epoch 4/100 | Total: 4.2006 | BCE: 2.4762 | Dice: 0.1762 | IoU: 0.0994
# [Train] Epoch 4/100 | Total: 4.0875 | BCE: 2.3335 | Dice: 0.1577 | IoU: 0.0883
# [Train] Epoch 4/100 | Total: 4.0934 | BCE: 2.3467 | Dice: 0.1623 | IoU: 0.0910
# [Train] Epoch 4/100 | Total: 4.1023 | BCE: 2.3641 | Dice: 0.1679 | IoU: 0.0939
# [Train] Epoch 4/100 | Total: 4.0844 | BCE: 2.3417 | Dice: 0.1649 | IoU: 0.0924
# [Train] Epoch 4/100 | Total: 4.2545 | BCE: 2.5695 | Dice: 0.2006 | IoU: 0.1145
# [Val] Epoch 4 | BCE Loss: 0.4351 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 4 | BCE Loss: 0.4397 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 4 | BCE Loss: 0.4914 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 4 | BCE Loss: 0.3931 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 4
#     Train Total Loss : 4.1506 | BCE: 2.4232 | Dice score: 0.1743 | IoU score: 0.0983
#     Val   BCE Loss   : 0.4398 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 5/100 | Total: 4.1535 | BCE: 2.4037 | Dice: 0.1605 | IoU: 0.0897
# [Train] Epoch 5/100 | Total: 4.0476 | BCE: 2.3089 | Dice: 0.1677 | IoU: 0.0937
# [Train] Epoch 5/100 | Total: 4.0987 | BCE: 2.3740 | Dice: 0.1763 | IoU: 0.0989
# [Train] Epoch 5/100 | Total: 4.0587 | BCE: 2.3061 | Dice: 0.1589 | IoU: 0.0884
# [Train] Epoch 5/100 | Total: 4.1088 | BCE: 2.3757 | Dice: 0.1711 | IoU: 0.0957
# [Train] Epoch 5/100 | Total: 4.0403 | BCE: 2.2984 | Dice: 0.1655 | IoU: 0.0926
# [Train] Epoch 5/100 | Total: 4.0706 | BCE: 2.3072 | Dice: 0.1518 | IoU: 0.0848
# [Train] Epoch 5/100 | Total: 3.9904 | BCE: 2.2465 | Dice: 0.1646 | IoU: 0.0915
# [Train] Epoch 5/100 | Total: 4.0105 | BCE: 2.2477 | Dice: 0.1527 | IoU: 0.0846
# [Train] Epoch 5/100 | Total: 4.0765 | BCE: 2.3370 | Dice: 0.1671 | IoU: 0.0933
# [Train] Epoch 5/100 | Total: 4.1460 | BCE: 2.3924 | Dice: 0.1584 | IoU: 0.0880
# [Train] Epoch 5/100 | Total: 3.9930 | BCE: 2.2314 | Dice: 0.1535 | IoU: 0.0848
# [Train] Epoch 5/100 | Total: 4.2642 | BCE: 2.5338 | Dice: 0.1727 | IoU: 0.0968
# [Val] Epoch 5 | BCE Loss: 0.4103 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 5 | BCE Loss: 0.4161 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 5 | BCE Loss: 0.4792 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 5 | BCE Loss: 0.3595 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 5
#     Train Total Loss : 4.0814 | BCE: 2.3356 | Dice score: 0.1631 | IoU score: 0.0910
#     Val   BCE Loss   : 0.4163 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 6/100 | Total: 4.0121 | BCE: 2.2563 | Dice: 0.1571 | IoU: 0.0871
# [Train] Epoch 6/100 | Total: 4.0663 | BCE: 2.3112 | Dice: 0.1577 | IoU: 0.0873
# [Train] Epoch 6/100 | Total: 4.0469 | BCE: 2.3027 | Dice: 0.1644 | IoU: 0.0914
# [Train] Epoch 6/100 | Total: 3.9764 | BCE: 2.2110 | Dice: 0.1511 | IoU: 0.0835
# [Train] Epoch 6/100 | Total: 3.9052 | BCE: 2.1389 | Dice: 0.1505 | IoU: 0.0832
# [Train] Epoch 6/100 | Total: 4.0367 | BCE: 2.2765 | Dice: 0.1541 | IoU: 0.0857
# [Train] Epoch 6/100 | Total: 3.9731 | BCE: 2.2126 | Dice: 0.1542 | IoU: 0.0853
# [Train] Epoch 6/100 | Total: 5.7504 | BCE: 4.0061 | Dice: 0.1644 | IoU: 0.0913
# [Train] Epoch 6/100 | Total: 4.3010 | BCE: 2.5166 | Dice: 0.1393 | IoU: 0.0763
# [Train] Epoch 6/100 | Total: 4.7197 | BCE: 2.9674 | Dice: 0.1595 | IoU: 0.0882
# [Train] Epoch 6/100 | Total: 5.2666 | BCE: 3.5021 | Dice: 0.1518 | IoU: 0.0837
# [Train] Epoch 6/100 | Total: 4.2022 | BCE: 2.4528 | Dice: 0.1614 | IoU: 0.0893
# [Train] Epoch 6/100 | Total: 3.9992 | BCE: 2.2298 | Dice: 0.1490 | IoU: 0.0817
# [Val] Epoch 6 | BCE Loss: 0.3944 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 6 | BCE Loss: 0.4028 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 6 | BCE Loss: 0.4787 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 6 | BCE Loss: 0.3350 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 6
#     Train Total Loss : 4.3274 | BCE: 2.5680 | Dice score: 0.1550 | IoU score: 0.0857
#     Val   BCE Loss   : 0.4027 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 7/100 | Total: 4.0694 | BCE: 2.2732 | Dice: 0.1318 | IoU: 0.0720
# [Train] Epoch 7/100 | Total: 4.1017 | BCE: 2.3274 | Dice: 0.1458 | IoU: 0.0799
# [Train] Epoch 7/100 | Total: 5.5857 | BCE: 3.8678 | Dice: 0.1807 | IoU: 0.1014
# [Train] Epoch 7/100 | Total: 3.9102 | BCE: 2.1393 | Dice: 0.1479 | IoU: 0.0812
# [Train] Epoch 7/100 | Total: 4.2439 | BCE: 2.4780 | Dice: 0.1507 | IoU: 0.0834
# [Train] Epoch 7/100 | Total: 9.5051 | BCE: 7.6745 | Dice: 0.1103 | IoU: 0.0592
# [Train] Epoch 7/100 | Total: 4.7798 | BCE: 3.0092 | Dice: 0.1478 | IoU: 0.0816
# [Train] Epoch 7/100 | Total: 4.3167 | BCE: 2.5872 | Dice: 0.1738 | IoU: 0.0967
# [Train] Epoch 7/100 | Total: 15.3564 | BCE: 13.4876 | Dice: 0.0856 | IoU: 0.0455
# [Train] Epoch 7/100 | Total: 4.6696 | BCE: 2.9121 | Dice: 0.1564 | IoU: 0.0862
# [Train] Epoch 7/100 | Total: 6.0115 | BCE: 4.2755 | Dice: 0.1696 | IoU: 0.0944
# [Train] Epoch 7/100 | Total: 4.2521 | BCE: 2.4814 | Dice: 0.1480 | IoU: 0.0813
# [Train] Epoch 7/100 | Total: 7.3858 | BCE: 5.6476 | Dice: 0.1672 | IoU: 0.0947
# [Val] Epoch 7 | BCE Loss: 0.4042 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 7 | BCE Loss: 0.4104 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 7 | BCE Loss: 0.4766 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 7 | BCE Loss: 0.3504 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 7
#     Train Total Loss : 6.0144 | BCE: 4.2431 | Dice score: 0.1474 | IoU score: 0.0813
#     Val   BCE Loss   : 0.4104 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 8/100 | Total: 4.4737 | BCE: 2.7123 | Dice: 0.1538 | IoU: 0.0848
# [Train] Epoch 8/100 | Total: 13.4452 | BCE: 11.5740 | Dice: 0.0843 | IoU: 0.0445
# [Train] Epoch 8/100 | Total: 4.6336 | BCE: 2.8675 | Dice: 0.1508 | IoU: 0.0831
# [Train] Epoch 8/100 | Total: 5.3202 | BCE: 3.5273 | Dice: 0.1339 | IoU: 0.0733
# [Train] Epoch 8/100 | Total: 6.2110 | BCE: 4.4478 | Dice: 0.1525 | IoU: 0.0843
# [Train] Epoch 8/100 | Total: 4.6155 | BCE: 2.8725 | Dice: 0.1651 | IoU: 0.0919
# [Train] Epoch 8/100 | Total: 4.5668 | BCE: 2.8177 | Dice: 0.1611 | IoU: 0.0898
# [Train] Epoch 8/100 | Total: 4.7015 | BCE: 2.9641 | Dice: 0.1685 | IoU: 0.0941
# [Train] Epoch 8/100 | Total: 5.0830 | BCE: 3.3385 | Dice: 0.1643 | IoU: 0.0912
# [Train] Epoch 8/100 | Total: 4.2321 | BCE: 2.4727 | Dice: 0.1548 | IoU: 0.0858
# [Train] Epoch 8/100 | Total: 4.4721 | BCE: 2.7239 | Dice: 0.1618 | IoU: 0.0901
# [Train] Epoch 8/100 | Total: 4.2059 | BCE: 2.4403 | Dice: 0.1510 | IoU: 0.0834
# [Train] Epoch 8/100 | Total: 4.1296 | BCE: 2.3554 | Dice: 0.1455 | IoU: 0.0802
# [Val] Epoch 8 | BCE Loss: 0.4193 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 8 | BCE Loss: 0.4253 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 8 | BCE Loss: 0.4851 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 8 | BCE Loss: 0.3727 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 8
#     Train Total Loss : 5.3916 | BCE: 3.6241 | Dice score: 0.1498 | IoU score: 0.0828
#     Val   BCE Loss   : 0.4256 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 9/100 | Total: 4.3136 | BCE: 2.5732 | Dice: 0.1666 | IoU: 0.0930
# [Train] Epoch 9/100 | Total: 4.2524 | BCE: 2.5030 | Dice: 0.1611 | IoU: 0.0896
# [Train] Epoch 9/100 | Total: 4.0590 | BCE: 2.2872 | Dice: 0.1469 | IoU: 0.0814
# [Train] Epoch 9/100 | Total: 4.0316 | BCE: 2.2759 | Dice: 0.1570 | IoU: 0.0873
# [Train] Epoch 9/100 | Total: 4.0847 | BCE: 2.3382 | Dice: 0.1626 | IoU: 0.0909
# [Train] Epoch 9/100 | Total: 4.1700 | BCE: 2.4450 | Dice: 0.1760 | IoU: 0.0990
# [Train] Epoch 9/100 | Total: 4.1129 | BCE: 2.3639 | Dice: 0.1611 | IoU: 0.0899
# [Train] Epoch 9/100 | Total: 4.1689 | BCE: 2.4310 | Dice: 0.1681 | IoU: 0.0940
# [Train] Epoch 9/100 | Total: 4.0599 | BCE: 2.3041 | Dice: 0.1572 | IoU: 0.0870
# [Train] Epoch 9/100 | Total: 4.0644 | BCE: 2.3391 | Dice: 0.1763 | IoU: 0.0983
# [Train] Epoch 9/100 | Total: 4.2011 | BCE: 2.4580 | Dice: 0.1646 | IoU: 0.0923
# [Train] Epoch 9/100 | Total: 4.0094 | BCE: 2.2490 | Dice: 0.1541 | IoU: 0.0855
# [Train] Epoch 9/100 | Total: 4.1331 | BCE: 2.4025 | Dice: 0.1725 | IoU: 0.0969
# [Val] Epoch 9 | BCE Loss: 0.4227 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 9 | BCE Loss: 0.4283 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 9 | BCE Loss: 0.4851 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 9 | BCE Loss: 0.3784 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 9
#     Train Total Loss : 4.1278 | BCE: 2.3823 | Dice score: 0.1634 | IoU score: 0.0911
#     Val   BCE Loss   : 0.4286 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 10/100 | Total: 4.1089 | BCE: 2.3693 | Dice: 0.1672 | IoU: 0.0932
# [Train] Epoch 10/100 | Total: 4.0008 | BCE: 2.2578 | Dice: 0.1652 | IoU: 0.0918
# [Train] Epoch 10/100 | Total: 4.1587 | BCE: 2.4336 | Dice: 0.1761 | IoU: 0.0988
# [Train] Epoch 10/100 | Total: 4.0499 | BCE: 2.2882 | Dice: 0.1531 | IoU: 0.0852
# [Train] Epoch 10/100 | Total: 4.0749 | BCE: 2.3500 | Dice: 0.1765 | IoU: 0.0986
# [Train] Epoch 10/100 | Total: 3.9320 | BCE: 2.1693 | Dice: 0.1529 | IoU: 0.0845
# [Train] Epoch 10/100 | Total: 4.0571 | BCE: 2.3164 | Dice: 0.1663 | IoU: 0.0930
# [Train] Epoch 10/100 | Total: 4.0522 | BCE: 2.3130 | Dice: 0.1675 | IoU: 0.0933
# [Train] Epoch 10/100 | Total: 4.0379 | BCE: 2.2654 | Dice: 0.1459 | IoU: 0.0816
# [Train] Epoch 10/100 | Total: 3.8862 | BCE: 2.1139 | Dice: 0.1467 | IoU: 0.0810
# [Train] Epoch 10/100 | Total: 4.0029 | BCE: 2.2583 | Dice: 0.1642 | IoU: 0.0912
# [Train] Epoch 10/100 | Total: 3.9786 | BCE: 2.2327 | Dice: 0.1632 | IoU: 0.0909
# [Train] Epoch 10/100 | Total: 4.1223 | BCE: 2.3899 | Dice: 0.1713 | IoU: 0.0964
# [Val] Epoch 10 | BCE Loss: 0.4151 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 10 | BCE Loss: 0.4209 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 10 | BCE Loss: 0.4812 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 10 | BCE Loss: 0.3677 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 10
#     Train Total Loss : 4.0356 | BCE: 2.2891 | Dice score: 0.1628 | IoU score: 0.0907
#     Val   BCE Loss   : 0.4212 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 11/100 | Total: 3.9935 | BCE: 2.2527 | Dice: 0.1665 | IoU: 0.0926
# [Train] Epoch 11/100 | Total: 4.0634 | BCE: 2.3343 | Dice: 0.1738 | IoU: 0.0971
# [Train] Epoch 11/100 | Total: 3.9013 | BCE: 2.1273 | Dice: 0.1454 | IoU: 0.0806
# [Train] Epoch 11/100 | Total: 3.8110 | BCE: 2.0310 | Dice: 0.1420 | IoU: 0.0780
# [Train] Epoch 11/100 | Total: 4.0594 | BCE: 2.3257 | Dice: 0.1709 | IoU: 0.0954
# [Train] Epoch 11/100 | Total: 3.9835 | BCE: 2.2559 | Dice: 0.1749 | IoU: 0.0975
# [Train] Epoch 11/100 | Total: 4.0713 | BCE: 2.3309 | Dice: 0.1665 | IoU: 0.0931
# [Train] Epoch 11/100 | Total: 3.9088 | BCE: 2.1300 | Dice: 0.1427 | IoU: 0.0786
# [Train] Epoch 11/100 | Total: 3.8686 | BCE: 2.1120 | Dice: 0.1567 | IoU: 0.0867
# [Train] Epoch 11/100 | Total: 4.1002 | BCE: 2.3592 | Dice: 0.1660 | IoU: 0.0930
# [Train] Epoch 11/100 | Total: 4.0256 | BCE: 2.3040 | Dice: 0.1784 | IoU: 0.1000
# [Train] Epoch 11/100 | Total: 3.9853 | BCE: 2.2259 | Dice: 0.1547 | IoU: 0.0859
# [Train] Epoch 11/100 | Total: 3.8345 | BCE: 2.0547 | Dice: 0.1422 | IoU: 0.0780
# [Val] Epoch 11 | BCE Loss: 0.4080 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 11 | BCE Loss: 0.4141 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 11 | BCE Loss: 0.4772 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 11 | BCE Loss: 0.3586 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 11
#     Train Total Loss : 3.9697 | BCE: 2.2187 | Dice score: 0.1600 | IoU score: 0.0889
#     Val   BCE Loss   : 0.4145 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 12/100 | Total: 3.7643 | BCE: 1.9854 | Dice: 0.1426 | IoU: 0.0785
# [Train] Epoch 12/100 | Total: 3.9030 | BCE: 2.1502 | Dice: 0.1594 | IoU: 0.0879
# [Train] Epoch 12/100 | Total: 4.0413 | BCE: 2.2917 | Dice: 0.1610 | IoU: 0.0895
# [Train] Epoch 12/100 | Total: 3.8690 | BCE: 2.0957 | Dice: 0.1462 | IoU: 0.0806
# [Train] Epoch 12/100 | Total: 4.0051 | BCE: 2.2635 | Dice: 0.1658 | IoU: 0.0926
# [Train] Epoch 12/100 | Total: 4.0086 | BCE: 2.2687 | Dice: 0.1668 | IoU: 0.0933
# [Train] Epoch 12/100 | Total: 4.0622 | BCE: 2.3198 | Dice: 0.1653 | IoU: 0.0923
# [Train] Epoch 12/100 | Total: 3.9235 | BCE: 2.1801 | Dice: 0.1651 | IoU: 0.0915
# [Train] Epoch 12/100 | Total: 4.1311 | BCE: 2.4149 | Dice: 0.1817 | IoU: 0.1021
# [Train] Epoch 12/100 | Total: 3.8265 | BCE: 2.0560 | Dice: 0.1478 | IoU: 0.0817
# [Train] Epoch 12/100 | Total: 3.8602 | BCE: 2.0949 | Dice: 0.1512 | IoU: 0.0836
# [Train] Epoch 12/100 | Total: 3.8355 | BCE: 2.0745 | Dice: 0.1539 | IoU: 0.0851
# [Train] Epoch 12/100 | Total: 3.9897 | BCE: 2.2616 | Dice: 0.1745 | IoU: 0.0973
# [Val] Epoch 12 | BCE Loss: 0.4033 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 12 | BCE Loss: 0.4098 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 12 | BCE Loss: 0.4743 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 12 | BCE Loss: 0.3534 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 12
#     Train Total Loss : 3.9400 | BCE: 2.1890 | Dice score: 0.1601 | IoU score: 0.0889
#     Val   BCE Loss   : 0.4102 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 13/100 | Total: 3.8946 | BCE: 2.1440 | Dice: 0.1605 | IoU: 0.0889
# [Train] Epoch 13/100 | Total: 4.0000 | BCE: 2.2552 | Dice: 0.1639 | IoU: 0.0913
# [Train] Epoch 13/100 | Total: 3.7929 | BCE: 2.0324 | Dice: 0.1543 | IoU: 0.0852
# [Train] Epoch 13/100 | Total: 3.7886 | BCE: 2.0474 | Dice: 0.1666 | IoU: 0.0923
# [Train] Epoch 13/100 | Total: 3.9373 | BCE: 2.1881 | Dice: 0.1611 | IoU: 0.0897
# [Train] Epoch 13/100 | Total: 3.9149 | BCE: 2.1638 | Dice: 0.1598 | IoU: 0.0892
# [Train] Epoch 13/100 | Total: 3.9464 | BCE: 2.1880 | Dice: 0.1552 | IoU: 0.0865
# [Train] Epoch 13/100 | Total: 3.8933 | BCE: 2.1635 | Dice: 0.1735 | IoU: 0.0967
# [Train] Epoch 13/100 | Total: 3.8641 | BCE: 2.1133 | Dice: 0.1601 | IoU: 0.0891
# [Train] Epoch 13/100 | Total: 3.9543 | BCE: 2.2062 | Dice: 0.1616 | IoU: 0.0904
# [Train] Epoch 13/100 | Total: 3.9255 | BCE: 2.1916 | Dice: 0.1708 | IoU: 0.0953
# [Train] Epoch 13/100 | Total: 3.8084 | BCE: 2.0565 | Dice: 0.1597 | IoU: 0.0884
# [Train] Epoch 13/100 | Total: 3.7111 | BCE: 1.9544 | Dice: 0.1568 | IoU: 0.0866
# [Val] Epoch 13 | BCE Loss: 0.4002 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 13 | BCE Loss: 0.4067 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 13 | BCE Loss: 0.4696 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 13 | BCE Loss: 0.3519 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 13
#     Train Total Loss : 3.8793 | BCE: 2.1311 | Dice score: 0.1618 | IoU score: 0.0900
#     Val   BCE Loss   : 0.4071 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 14/100 | Total: 3.8036 | BCE: 2.0597 | Dice: 0.1647 | IoU: 0.0914
# [Train] Epoch 14/100 | Total: 3.7066 | BCE: 1.9362 | Dice: 0.1478 | IoU: 0.0818
# [Train] Epoch 14/100 | Total: 3.8213 | BCE: 2.0790 | Dice: 0.1655 | IoU: 0.0921
# [Train] Epoch 14/100 | Total: 4.1166 | BCE: 2.3875 | Dice: 0.1734 | IoU: 0.0975
# [Train] Epoch 14/100 | Total: 3.8205 | BCE: 2.0606 | Dice: 0.1544 | IoU: 0.0857
# [Train] Epoch 14/100 | Total: 3.8827 | BCE: 2.1407 | Dice: 0.1657 | IoU: 0.0923
# [Train] Epoch 14/100 | Total: 3.7561 | BCE: 2.0091 | Dice: 0.1627 | IoU: 0.0904
# [Train] Epoch 14/100 | Total: 3.8748 | BCE: 2.1304 | Dice: 0.1640 | IoU: 0.0916
# [Train] Epoch 14/100 | Total: 3.8931 | BCE: 2.1769 | Dice: 0.1818 | IoU: 0.1020
# [Train] Epoch 14/100 | Total: 3.7990 | BCE: 2.0708 | Dice: 0.1744 | IoU: 0.0974
# [Train] Epoch 14/100 | Total: 3.8437 | BCE: 2.1161 | Dice: 0.1746 | IoU: 0.0978
# [Train] Epoch 14/100 | Total: 3.8137 | BCE: 2.0801 | Dice: 0.1709 | IoU: 0.0955
# [Train] Epoch 14/100 | Total: 3.6268 | BCE: 1.8754 | Dice: 0.1601 | IoU: 0.0886
# [Val] Epoch 14 | BCE Loss: 0.3911 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 14 | BCE Loss: 0.3977 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 14 | BCE Loss: 0.4616 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 14 | BCE Loss: 0.3431 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 14
#     Train Total Loss : 3.8276 | BCE: 2.0864 | Dice score: 0.1662 | IoU score: 0.0926
#     Val   BCE Loss   : 0.3984 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 15/100 | Total: 3.7439 | BCE: 1.9858 | Dice: 0.1555 | IoU: 0.0865
# [Train] Epoch 15/100 | Total: 3.8564 | BCE: 2.1161 | Dice: 0.1668 | IoU: 0.0929
# [Train] Epoch 15/100 | Total: 3.6629 | BCE: 1.9293 | Dice: 0.1713 | IoU: 0.0952
# [Train] Epoch 15/100 | Total: 3.8937 | BCE: 2.1763 | Dice: 0.1810 | IoU: 0.1017
# [Train] Epoch 15/100 | Total: 3.7788 | BCE: 2.0382 | Dice: 0.1663 | IoU: 0.0930
# [Train] Epoch 15/100 | Total: 3.8277 | BCE: 2.0932 | Dice: 0.1703 | IoU: 0.0953
# [Train] Epoch 15/100 | Total: 3.8106 | BCE: 2.0906 | Dice: 0.1793 | IoU: 0.1007
# [Train] Epoch 15/100 | Total: 3.7077 | BCE: 1.9725 | Dice: 0.1700 | IoU: 0.0948
# [Train] Epoch 15/100 | Total: 3.6989 | BCE: 1.9438 | Dice: 0.1574 | IoU: 0.0876
# [Train] Epoch 15/100 | Total: 3.8834 | BCE: 2.1745 | Dice: 0.1863 | IoU: 0.1047
# [Train] Epoch 15/100 | Total: 3.7649 | BCE: 2.0435 | Dice: 0.1787 | IoU: 0.1000
# [Train] Epoch 15/100 | Total: 3.8287 | BCE: 2.1010 | Dice: 0.1745 | IoU: 0.0978
# [Train] Epoch 15/100 | Total: 3.8933 | BCE: 2.1916 | Dice: 0.1906 | IoU: 0.1078
# [Val] Epoch 15 | BCE Loss: 0.3768 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 15 | BCE Loss: 0.3840 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 15 | BCE Loss: 0.4464 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 15 | BCE Loss: 0.3314 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 15
#     Train Total Loss : 3.7962 | BCE: 2.0659 | Dice score: 0.1729 | IoU score: 0.0968
#     Val   BCE Loss   : 0.3847 | Dice score: 0.0000 | IoU score : 0.0000
# [Train] Epoch 16/100 | Total: 3.7000 | BCE: 1.9804 | Dice: 0.1795 | IoU: 0.1008
# [Train] Epoch 16/100 | Total: 3.7480 | BCE: 2.0223 | Dice: 0.1755 | IoU: 0.0988
# [Train] Epoch 16/100 | Total: 3.8084 | BCE: 2.1015 | Dice: 0.1873 | IoU: 0.1058
# [Train] Epoch 16/100 | Total: 3.7129 | BCE: 1.9994 | Dice: 0.1833 | IoU: 0.1032
# [Train] Epoch 16/100 | Total: 3.6369 | BCE: 1.9046 | Dice: 0.1718 | IoU: 0.0959
# [Train] Epoch 16/100 | Total: 3.6495 | BCE: 1.9266 | Dice: 0.1775 | IoU: 0.0997
# [Train] Epoch 16/100 | Total: 3.8498 | BCE: 2.1267 | Dice: 0.1773 | IoU: 0.0996
# [Train] Epoch 16/100 | Total: 3.7747 | BCE: 2.0725 | Dice: 0.1904 | IoU: 0.1074
# [Train] Epoch 16/100 | Total: 3.7609 | BCE: 2.0596 | Dice: 0.1907 | IoU: 0.1080
# [Train] Epoch 16/100 | Total: 3.6446 | BCE: 1.9426 | Dice: 0.1906 | IoU: 0.1074
# [Train] Epoch 16/100 | Total: 3.7197 | BCE: 2.0250 | Dice: 0.1947 | IoU: 0.1105
# [Train] Epoch 16/100 | Total: 3.6490 | BCE: 1.9529 | Dice: 0.1937 | IoU: 0.1101
# [Train] Epoch 16/100 | Total: 4.0473 | BCE: 2.3730 | Dice: 0.2071 | IoU: 0.1186
# [Val] Epoch 16 | BCE Loss: 0.3551 | Dice: 0.0004 | IoU: 0.0002
# [Val] Epoch 16 | BCE Loss: 0.3628 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 16 | BCE Loss: 0.4257 | Dice: 0.0000 | IoU: 0.0000
# [Val] Epoch 16 | BCE Loss: 0.3100 | Dice: 0.0000 | IoU: 0.0000
# ==> Epoch 16
#     Train Total Loss : 3.7463 | BCE: 2.0375 | Dice score: 0.1861 | IoU score: 0.1051
#     Val   BCE Loss   : 0.3634 | Dice score: 0.0001 | IoU score : 0.0000
# [Train] Epoch 17/100 | Total: 3.5895 | BCE: 1.8650 | Dice: 0.1764 | IoU: 0.0991
# [Train] Epoch 17/100 | Total: 3.7516 | BCE: 2.0738 | Dice: 0.2051 | IoU: 0.1171
# [Train] Epoch 17/100 | Total: 3.7083 | BCE: 2.0192 | Dice: 0.1982 | IoU: 0.1127
# [Train] Epoch 17/100 | Total: 3.7122 | BCE: 2.0727 | Dice: 0.2287 | IoU: 0.1319
# [Train] Epoch 17/100 | Total: 3.6303 | BCE: 1.9224 | Dice: 0.1864 | IoU: 0.1057
# [Train] Epoch 17/100 | Total: 3.6177 | BCE: 1.9768 | Dice: 0.2277 | IoU: 0.1314
# [Train] Epoch 17/100 | Total: 3.6851 | BCE: 2.0344 | Dice: 0.2211 | IoU: 0.1281
# [Train] Epoch 17/100 | Total: 3.6657 | BCE: 2.0153 | Dice: 0.2216 | IoU: 0.1279
# [Train] Epoch 17/100 | Total: 3.7967 | BCE: 2.1394 | Dice: 0.2175 | IoU: 0.1252
# [Train] Epoch 17/100 | Total: 3.5905 | BCE: 1.9043 | Dice: 0.1999 | IoU: 0.1139
# [Train] Epoch 17/100 | Total: 3.6298 | BCE: 1.9466 | Dice: 0.2018 | IoU: 0.1150
# [Train] Epoch 17/100 | Total: 3.4480 | BCE: 1.7861 | Dice: 0.2148 | IoU: 0.1233
# [Train] Epoch 17/100 | Total: 3.4680 | BCE: 1.8745 | Dice: 0.2552 | IoU: 0.1514
# [Val] Epoch 17 | BCE Loss: 0.3254 | Dice: 0.0870 | IoU: 0.0544
# [Val] Epoch 17 | BCE Loss: 0.3315 | Dice: 0.0575 | IoU: 0.0333
# [Val] Epoch 17 | BCE Loss: 0.3938 | Dice: 0.0373 | IoU: 0.0209
# [Val] Epoch 17 | BCE Loss: 0.2813 | Dice: 0.0532 | IoU: 0.0322
# ==> Epoch 17
#     Train Total Loss : 3.6379 | BCE: 1.9716 | Dice score: 0.2119 | IoU score: 0.1217
#     Val   BCE Loss   : 0.3330 | Dice score: 0.0588 | IoU score : 0.0352
# [Train] Epoch 18/100 | Total: 3.6401 | BCE: 2.0217 | Dice: 0.2410 | IoU: 0.1405
# [Train] Epoch 18/100 | Total: 3.5634 | BCE: 1.9331 | Dice: 0.2330 | IoU: 0.1367
# [Train] Epoch 18/100 | Total: 3.5465 | BCE: 1.9070 | Dice: 0.2272 | IoU: 0.1333
# [Train] Epoch 18/100 | Total: 3.4195 | BCE: 1.8157 | Dice: 0.2493 | IoU: 0.1469
# [Train] Epoch 18/100 | Total: 3.5507 | BCE: 1.9625 | Dice: 0.2581 | IoU: 0.1536
# [Train] Epoch 18/100 | Total: 3.6744 | BCE: 2.0771 | Dice: 0.2531 | IoU: 0.1497
# [Train] Epoch 18/100 | Total: 3.5051 | BCE: 1.9520 | Dice: 0.2794 | IoU: 0.1675
# [Train] Epoch 18/100 | Total: 3.5279 | BCE: 1.9870 | Dice: 0.2851 | IoU: 0.1740
# [Train] Epoch 18/100 | Total: 3.4634 | BCE: 1.9277 | Dice: 0.2877 | IoU: 0.1766
# [Train] Epoch 18/100 | Total: 3.5757 | BCE: 2.0643 | Dice: 0.3030 | IoU: 0.1856
# [Train] Epoch 18/100 | Total: 3.3305 | BCE: 1.8546 | Dice: 0.3224 | IoU: 0.2016
# [Train] Epoch 18/100 | Total: 3.3541 | BCE: 1.8206 | Dice: 0.2886 | IoU: 0.1780
# [Train] Epoch 18/100 | Total: 3.5916 | BCE: 2.1501 | Dice: 0.3397 | IoU: 0.2188
# [Val] Epoch 18 | BCE Loss: 0.3126 | Dice: 0.3932 | IoU: 0.2734
# [Val] Epoch 18 | BCE Loss: 0.3186 | Dice: 0.3994 | IoU: 0.2794
# [Val] Epoch 18 | BCE Loss: 0.3800 | Dice: 0.3875 | IoU: 0.2712
# [Val] Epoch 18 | BCE Loss: 0.2827 | Dice: 0.2909 | IoU: 0.1979
# ==> Epoch 18
#     Train Total Loss : 3.5187 | BCE: 1.9595 | Dice score: 0.2744 | IoU score: 0.1664
#     Val   BCE Loss   : 0.3235 | Dice score: 0.3678 | IoU score : 0.2554
# [Train] Epoch 19/100 | Total: 3.4944 | BCE: 2.0418 | Dice: 0.3346 | IoU: 0.2128
# [Train] Epoch 19/100 | Total: 3.4531 | BCE: 2.0080 | Dice: 0.3388 | IoU: 0.2161
# [Train] Epoch 19/100 | Total: 3.4219 | BCE: 1.9427 | Dice: 0.3183 | IoU: 0.2025
# [Train] Epoch 19/100 | Total: 3.2387 | BCE: 1.7782 | Dice: 0.3292 | IoU: 0.2103
# [Train] Epoch 19/100 | Total: 3.4031 | BCE: 1.8832 | Dice: 0.2953 | IoU: 0.1848
# [Train] Epoch 19/100 | Total: 3.2698 | BCE: 1.8651 | Dice: 0.3613 | IoU: 0.2340
# [Train] Epoch 19/100 | Total: 3.3520 | BCE: 1.9395 | Dice: 0.3554 | IoU: 0.2320
# [Train] Epoch 19/100 | Total: 3.2120 | BCE: 1.8267 | Dice: 0.3717 | IoU: 0.2430
# [Train] Epoch 19/100 | Total: 3.4609 | BCE: 2.0204 | Dice: 0.3393 | IoU: 0.2202
# [Train] Epoch 19/100 | Total: 3.1610 | BCE: 1.8793 | Dice: 0.4266 | IoU: 0.2917
# [Train] Epoch 19/100 | Total: 3.1815 | BCE: 1.7877 | Dice: 0.3657 | IoU: 0.2405
# [Train] Epoch 19/100 | Total: 3.5245 | BCE: 2.1114 | Dice: 0.3536 | IoU: 0.2333
# [Train] Epoch 19/100 | Total: 3.1481 | BCE: 1.9300 | Dice: 0.4646 | IoU: 0.3173
# [Val] Epoch 19 | BCE Loss: 0.4125 | Dice: 0.4450 | IoU: 0.3095
# [Val] Epoch 19 | BCE Loss: 0.4057 | Dice: 0.4447 | IoU: 0.3119
# [Val] Epoch 19 | BCE Loss: 0.4696 | Dice: 0.4859 | IoU: 0.3530
# [Val] Epoch 19 | BCE Loss: 0.3748 | Dice: 0.3598 | IoU: 0.2396
# ==> Epoch 19
#     Train Total Loss : 3.3324 | BCE: 1.9242 | Dice score: 0.3580 | IoU score: 0.2337
#     Val   BCE Loss   : 0.4157 | Dice score: 0.4338 | IoU score : 0.3035
# [Train] Epoch 20/100 | Total: 3.3404 | BCE: 2.0358 | Dice: 0.4118 | IoU: 0.2836
# [Train] Epoch 20/100 | Total: 3.2076 | BCE: 1.9424 | Dice: 0.4340 | IoU: 0.3007
# [Train] Epoch 20/100 | Total: 3.4293 | BCE: 2.0636 | Dice: 0.3804 | IoU: 0.2538
# [Train] Epoch 20/100 | Total: 3.3764 | BCE: 1.9876 | Dice: 0.3677 | IoU: 0.2435
# [Train] Epoch 20/100 | Total: 3.3640 | BCE: 1.9119 | Dice: 0.3327 | IoU: 0.2151
# [Train] Epoch 20/100 | Total: 3.3563 | BCE: 1.9883 | Dice: 0.3795 | IoU: 0.2525
# [Train] Epoch 20/100 | Total: 3.2206 | BCE: 1.8555 | Dice: 0.3825 | IoU: 0.2524
# [Train] Epoch 20/100 | Total: 3.1871 | BCE: 1.8124 | Dice: 0.3754 | IoU: 0.2499
# [Train] Epoch 20/100 | Total: 3.6186 | BCE: 2.2414 | Dice: 0.3736 | IoU: 0.2492
# [Train] Epoch 20/100 | Total: 3.1585 | BCE: 1.7976 | Dice: 0.3857 | IoU: 0.2534
# [Train] Epoch 20/100 | Total: 3.2173 | BCE: 1.7874 | Dice: 0.3465 | IoU: 0.2236
# [Train] Epoch 20/100 | Total: 3.1140 | BCE: 1.7434 | Dice: 0.3781 | IoU: 0.2513
# [Train] Epoch 20/100 | Total: 3.1912 | BCE: 1.8705 | Dice: 0.4073 | IoU: 0.2720
# [Val] Epoch 20 | BCE Loss: 0.4348 | Dice: 0.4347 | IoU: 0.3004
# [Val] Epoch 20 | BCE Loss: 0.4078 | Dice: 0.4618 | IoU: 0.3236
# [Val] Epoch 20 | BCE Loss: 0.4290 | Dice: 0.5043 | IoU: 0.3704
# [Val] Epoch 20 | BCE Loss: 0.4065 | Dice: 0.3638 | IoU: 0.2473
# ==> Epoch 20
#     Train Total Loss : 3.2909 | BCE: 1.9260 | Dice score: 0.3812 | IoU score: 0.2539
#     Val   BCE Loss   : 0.4195 | Dice score: 0.4412 | IoU score : 0.3104
# [Train] Epoch 21/100 | Total: 3.1726 | BCE: 1.8038 | Dice: 0.3777 | IoU: 0.2535
# [Train] Epoch 21/100 | Total: 3.1197 | BCE: 1.8121 | Dice: 0.4103 | IoU: 0.2822
# [Train] Epoch 21/100 | Total: 3.2697 | BCE: 1.9559 | Dice: 0.4106 | IoU: 0.2756
# [Train] Epoch 21/100 | Total: 3.1811 | BCE: 1.9445 | Dice: 0.4511 | IoU: 0.3123
# [Train] Epoch 21/100 | Total: 3.3697 | BCE: 2.0844 | Dice: 0.4266 | IoU: 0.2881
# [Train] Epoch 21/100 | Total: 2.9999 | BCE: 1.7703 | Dice: 0.4542 | IoU: 0.3162
# [Train] Epoch 21/100 | Total: 3.1830 | BCE: 1.8991 | Dice: 0.4260 | IoU: 0.2901
# [Train] Epoch 21/100 | Total: 3.2837 | BCE: 1.9795 | Dice: 0.4130 | IoU: 0.2829
# [Train] Epoch 21/100 | Total: 3.0566 | BCE: 1.7012 | Dice: 0.3844 | IoU: 0.2601
# [Train] Epoch 21/100 | Total: 3.2577 | BCE: 1.8974 | Dice: 0.3830 | IoU: 0.2567
# [Train] Epoch 21/100 | Total: 3.1718 | BCE: 1.8948 | Dice: 0.4292 | IoU: 0.2938
# [Train] Epoch 21/100 | Total: 3.3472 | BCE: 1.9829 | Dice: 0.3791 | IoU: 0.2565
# [Train] Epoch 21/100 | Total: 2.9595 | BCE: 1.6957 | Dice: 0.4350 | IoU: 0.3011
# [Val] Epoch 21 | BCE Loss: 0.3518 | Dice: 0.4528 | IoU: 0.3167
# [Val] Epoch 21 | BCE Loss: 0.3224 | Dice: 0.4913 | IoU: 0.3528
# [Val] Epoch 21 | BCE Loss: 0.3941 | Dice: 0.5090 | IoU: 0.3731
# [Val] Epoch 21 | BCE Loss: 0.3070 | Dice: 0.3570 | IoU: 0.2362
# ==> Epoch 21
#     Train Total Loss : 3.1825 | BCE: 1.8786 | Dice score: 0.4139 | IoU score: 0.2822
#     Val   BCE Loss   : 0.3438 | Dice score: 0.4525 | IoU score : 0.3197
# [Train] Epoch 22/100 | Total: 3.1261 | BCE: 1.8244 | Dice: 0.4167 | IoU: 0.2817
# [Train] Epoch 22/100 | Total: 3.1958 | BCE: 1.8267 | Dice: 0.3763 | IoU: 0.2546
# [Train] Epoch 22/100 | Total: 3.0699 | BCE: 1.7482 | Dice: 0.4058 | IoU: 0.2724
# [Train] Epoch 22/100 | Total: 3.2266 | BCE: 2.0006 | Dice: 0.4554 | IoU: 0.3186
# [Train] Epoch 22/100 | Total: 3.3017 | BCE: 2.0235 | Dice: 0.4255 | IoU: 0.2963
# [Train] Epoch 22/100 | Total: 3.2846 | BCE: 1.9749 | Dice: 0.4079 | IoU: 0.2824
# [Train] Epoch 22/100 | Total: 2.9744 | BCE: 1.6800 | Dice: 0.4162 | IoU: 0.2894
# [Train] Epoch 22/100 | Total: 3.0278 | BCE: 1.6540 | Dice: 0.3749 | IoU: 0.2513
# [Train] Epoch 22/100 | Total: 3.0947 | BCE: 1.7763 | Dice: 0.4060 | IoU: 0.2756
# [Train] Epoch 22/100 | Total: 3.2461 | BCE: 1.9253 | Dice: 0.4067 | IoU: 0.2725
# [Train] Epoch 22/100 | Total: 3.0606 | BCE: 1.8276 | Dice: 0.4522 | IoU: 0.3148
# [Train] Epoch 22/100 | Total: 2.9759 | BCE: 1.8073 | Dice: 0.4861 | IoU: 0.3453
# [Train] Epoch 22/100 | Total: 3.3713 | BCE: 2.0342 | Dice: 0.3929 | IoU: 0.2700
# [Val] Epoch 22 | BCE Loss: 0.3711 | Dice: 0.4717 | IoU: 0.3339
# [Val] Epoch 22 | BCE Loss: 0.3604 | Dice: 0.4679 | IoU: 0.3356
# [Val] Epoch 22 | BCE Loss: 0.4153 | Dice: 0.5034 | IoU: 0.3707
# [Val] Epoch 22 | BCE Loss: 0.3381 | Dice: 0.3813 | IoU: 0.2593
# ==> Epoch 22
#     Train Total Loss : 3.1504 | BCE: 1.8541 | Dice score: 0.4171 | IoU score: 0.2865
#     Val   BCE Loss   : 0.3712 | Dice score: 0.4561 | IoU score : 0.3249
# [Train] Epoch 23/100 | Total: 2.9393 | BCE: 1.6047 | Dice: 0.3960 | IoU: 0.2694
# [Train] Epoch 23/100 | Total: 3.4250 | BCE: 2.0465 | Dice: 0.3747 | IoU: 0.2468
# [Train] Epoch 23/100 | Total: 3.1756 | BCE: 1.7891 | Dice: 0.3679 | IoU: 0.2456
# [Train] Epoch 23/100 | Total: 3.3315 | BCE: 1.9974 | Dice: 0.3945 | IoU: 0.2714
# [Train] Epoch 23/100 | Total: 3.1517 | BCE: 1.8497 | Dice: 0.4140 | IoU: 0.2840
# [Train] Epoch 23/100 | Total: 3.2931 | BCE: 2.0264 | Dice: 0.4327 | IoU: 0.3006
# [Train] Epoch 23/100 | Total: 3.0878 | BCE: 1.8059 | Dice: 0.4263 | IoU: 0.2918
# [Train] Epoch 23/100 | Total: 3.0376 | BCE: 1.6831 | Dice: 0.3873 | IoU: 0.2582
# [Train] Epoch 23/100 | Total: 3.3096 | BCE: 1.9366 | Dice: 0.3775 | IoU: 0.2494
# [Train] Epoch 23/100 | Total: 3.1925 | BCE: 1.8157 | Dice: 0.3733 | IoU: 0.2499
# [Train] Epoch 23/100 | Total: 3.2621 | BCE: 1.8982 | Dice: 0.3819 | IoU: 0.2542
# [Train] Epoch 23/100 | Total: 3.2288 | BCE: 1.9451 | Dice: 0.4269 | IoU: 0.2894
# [Train] Epoch 23/100 | Total: 3.1257 | BCE: 1.7662 | Dice: 0.3863 | IoU: 0.2542
# [Val] Epoch 23 | BCE Loss: 0.4172 | Dice: 0.4499 | IoU: 0.3147
# [Val] Epoch 23 | BCE Loss: 0.3831 | Dice: 0.4644 | IoU: 0.3290
# [Val] Epoch 23 | BCE Loss: 0.4019 | Dice: 0.5168 | IoU: 0.3830
# [Val] Epoch 23 | BCE Loss: 0.4063 | Dice: 0.3747 | IoU: 0.2563
# ==> Epoch 23
#     Train Total Loss : 3.1970 | BCE: 1.8588 | Dice score: 0.3953 | IoU score: 0.2665
#     Val   BCE Loss   : 0.4021 | Dice score: 0.4515 | IoU score : 0.3208
# [Train] Epoch 24/100 | Total: 3.2117 | BCE: 1.9169 | Dice: 0.4197 | IoU: 0.2855
# [Train] Epoch 24/100 | Total: 3.1228 | BCE: 1.8189 | Dice: 0.4125 | IoU: 0.2837
# [Train] Epoch 24/100 | Total: 2.9374 | BCE: 1.6856 | Dice: 0.4368 | IoU: 0.3114
# [Train] Epoch 24/100 | Total: 3.0078 | BCE: 1.6700 | Dice: 0.3966 | IoU: 0.2657
# [Train] Epoch 24/100 | Total: 3.0050 | BCE: 1.7115 | Dice: 0.4181 | IoU: 0.2884
# [Train] Epoch 24/100 | Total: 3.5146 | BCE: 2.1829 | Dice: 0.3989 | IoU: 0.2694
# [Train] Epoch 24/100 | Total: 3.1868 | BCE: 1.9264 | Dice: 0.4355 | IoU: 0.3041
# [Train] Epoch 24/100 | Total: 3.0619 | BCE: 1.7553 | Dice: 0.4138 | IoU: 0.2796
# [Train] Epoch 24/100 | Total: 3.3061 | BCE: 2.0738 | Dice: 0.4518 | IoU: 0.3159
# [Train] Epoch 24/100 | Total: 3.1424 | BCE: 1.8347 | Dice: 0.4094 | IoU: 0.2829
# [Train] Epoch 24/100 | Total: 3.1580 | BCE: 1.8361 | Dice: 0.4043 | IoU: 0.2739
# [Train] Epoch 24/100 | Total: 3.0727 | BCE: 1.7237 | Dice: 0.3890 | IoU: 0.2621
# [Train] Epoch 24/100 | Total: 2.8770 | BCE: 1.5459 | Dice: 0.3970 | IoU: 0.2720
# [Val] Epoch 24 | BCE Loss: 0.3432 | Dice: 0.4627 | IoU: 0.3244
# [Val] Epoch 24 | BCE Loss: 0.3092 | Dice: 0.4918 | IoU: 0.3570
# [Val] Epoch 24 | BCE Loss: 0.3778 | Dice: 0.4810 | IoU: 0.3593
# [Val] Epoch 24 | BCE Loss: 0.2966 | Dice: 0.3525 | IoU: 0.2405
# ==> Epoch 24
#     Train Total Loss : 3.1234 | BCE: 1.8217 | Dice score: 0.4141 | IoU score: 0.2842
#     Val   BCE Loss   : 0.3317 | Dice score: 0.4470 | IoU score : 0.3203
# [Train] Epoch 25/100 | Total: 3.0032 | BCE: 1.7132 | Dice: 0.4227 | IoU: 0.2874
# [Train] Epoch 25/100 | Total: 3.0680 | BCE: 1.6726 | Dice: 0.3624 | IoU: 0.2422
# [Train] Epoch 25/100 | Total: 3.4318 | BCE: 2.0989 | Dice: 0.3986 | IoU: 0.2685
# [Train] Epoch 25/100 | Total: 2.9751 | BCE: 1.7268 | Dice: 0.4463 | IoU: 0.3054
# [Train] Epoch 25/100 | Total: 3.2327 | BCE: 1.8808 | Dice: 0.3860 | IoU: 0.2621
# [Train] Epoch 25/100 | Total: 3.2387 | BCE: 1.9812 | Dice: 0.4394 | IoU: 0.3030
# [Train] Epoch 25/100 | Total: 3.2456 | BCE: 2.0008 | Dice: 0.4409 | IoU: 0.3143
# [Train] Epoch 25/100 | Total: 3.0780 | BCE: 1.7740 | Dice: 0.4143 | IoU: 0.2817
# [Train] Epoch 25/100 | Total: 3.0243 | BCE: 1.7304 | Dice: 0.4187 | IoU: 0.2874
# [Train] Epoch 25/100 | Total: 3.0319 | BCE: 1.6926 | Dice: 0.3931 | IoU: 0.2676
# [Train] Epoch 25/100 | Total: 3.1124 | BCE: 1.7738 | Dice: 0.3954 | IoU: 0.2660
# [Train] Epoch 25/100 | Total: 3.1672 | BCE: 1.8344 | Dice: 0.3988 | IoU: 0.2683
# [Train] Epoch 25/100 | Total: 2.8800 | BCE: 1.6405 | Dice: 0.4517 | IoU: 0.3088
# [Val] Epoch 25 | BCE Loss: 0.3959 | Dice: 0.4491 | IoU: 0.3153
# [Val] Epoch 25 | BCE Loss: 0.3505 | Dice: 0.4964 | IoU: 0.3592
# [Val] Epoch 25 | BCE Loss: 0.3932 | Dice: 0.5269 | IoU: 0.3939
# [Val] Epoch 25 | BCE Loss: 0.3789 | Dice: 0.3871 | IoU: 0.2647
# ==> Epoch 25
#     Train Total Loss : 3.1145 | BCE: 1.8092 | Dice score: 0.4129 | IoU score: 0.2817
#     Val   BCE Loss   : 0.3796 | Dice score: 0.4649 | IoU score : 0.3333
# [Train] Epoch 26/100 | Total: 2.9514 | BCE: 1.7125 | Dice: 0.4491 | IoU: 0.3119
# [Train] Epoch 26/100 | Total: 2.8748 | BCE: 1.5889 | Dice: 0.4198 | IoU: 0.2943
# [Train] Epoch 26/100 | Total: 3.1824 | BCE: 1.8867 | Dice: 0.4187 | IoU: 0.2856
# [Train] Epoch 26/100 | Total: 2.9623 | BCE: 1.7451 | Dice: 0.4586 | IoU: 0.3242
# [Train] Epoch 26/100 | Total: 3.1586 | BCE: 1.8669 | Dice: 0.4200 | IoU: 0.2884
# [Train] Epoch 26/100 | Total: 3.4348 | BCE: 2.0429 | Dice: 0.3643 | IoU: 0.2439
# [Train] Epoch 26/100 | Total: 3.0395 | BCE: 1.8601 | Dice: 0.4808 | IoU: 0.3398
# [Train] Epoch 26/100 | Total: 3.3207 | BCE: 2.0642 | Dice: 0.4353 | IoU: 0.3081
# [Train] Epoch 26/100 | Total: 2.9637 | BCE: 1.7015 | Dice: 0.4367 | IoU: 0.3011
# [Train] Epoch 26/100 | Total: 3.2118 | BCE: 1.9468 | Dice: 0.4323 | IoU: 0.3028
# [Train] Epoch 26/100 | Total: 2.9534 | BCE: 1.6618 | Dice: 0.4216 | IoU: 0.2868
# [Train] Epoch 26/100 | Total: 2.9606 | BCE: 1.6918 | Dice: 0.4335 | IoU: 0.2977
# [Train] Epoch 26/100 | Total: 3.2192 | BCE: 1.7863 | Dice: 0.3394 | IoU: 0.2277
# [Val] Epoch 26 | BCE Loss: 0.3119 | Dice: 0.4611 | IoU: 0.3267
# [Val] Epoch 26 | BCE Loss: 0.2837 | Dice: 0.5009 | IoU: 0.3675
# [Val] Epoch 26 | BCE Loss: 0.3606 | Dice: 0.4910 | IoU: 0.3625
# [Val] Epoch 26 | BCE Loss: 0.2646 | Dice: 0.3282 | IoU: 0.2239
# ==> Epoch 26
#     Train Total Loss : 3.0949 | BCE: 1.8120 | Dice score: 0.4238 | IoU score: 0.2933
#     Val   BCE Loss   : 0.3052 | Dice score: 0.4453 | IoU score : 0.3201
# [Train] Epoch 27/100 | Total: 3.0735 | BCE: 1.7294 | Dice: 0.3933 | IoU: 0.2626
# [Train] Epoch 27/100 | Total: 3.1499 | BCE: 1.8168 | Dice: 0.3998 | IoU: 0.2671
# [Train] Epoch 27/100 | Total: 2.9717 | BCE: 1.6190 | Dice: 0.3871 | IoU: 0.2602
# [Train] Epoch 27/100 | Total: 3.1494 | BCE: 1.8314 | Dice: 0.4072 | IoU: 0.2748
# [Train] Epoch 27/100 | Total: 2.9041 | BCE: 1.6428 | Dice: 0.4340 | IoU: 0.3048
# [Train] Epoch 27/100 | Total: 3.0817 | BCE: 1.8672 | Dice: 0.4645 | IoU: 0.3210
# [Train] Epoch 27/100 | Total: 3.0494 | BCE: 1.7401 | Dice: 0.4074 | IoU: 0.2832
# [Train] Epoch 27/100 | Total: 3.0836 | BCE: 1.8373 | Dice: 0.4442 | IoU: 0.3095
# [Train] Epoch 27/100 | Total: 2.9828 | BCE: 1.7407 | Dice: 0.4482 | IoU: 0.3097
# [Train] Epoch 27/100 | Total: 2.8604 | BCE: 1.6383 | Dice: 0.4575 | IoU: 0.3204
# [Train] Epoch 27/100 | Total: 2.8944 | BCE: 1.6571 | Dice: 0.4467 | IoU: 0.3161
# [Train] Epoch 27/100 | Total: 3.1750 | BCE: 1.9337 | Dice: 0.4495 | IoU: 0.3092
# [Train] Epoch 27/100 | Total: 2.7552 | BCE: 1.5371 | Dice: 0.4607 | IoU: 0.3212
# [Val] Epoch 27 | BCE Loss: 0.3724 | Dice: 0.4720 | IoU: 0.3344
# [Val] Epoch 27 | BCE Loss: 0.3219 | Dice: 0.5088 | IoU: 0.3719
# [Val] Epoch 27 | BCE Loss: 0.4023 | Dice: 0.5116 | IoU: 0.3836
# [Val] Epoch 27 | BCE Loss: 0.3138 | Dice: 0.3719 | IoU: 0.2533
# ==> Epoch 27
#     Train Total Loss : 3.0101 | BCE: 1.7378 | Dice score: 0.4308 | IoU score: 0.2969
#     Val   BCE Loss   : 0.3526 | Dice score: 0.4661 | IoU score : 0.3358
# [Train] Epoch 28/100 | Total: 3.0027 | BCE: 1.6844 | Dice: 0.4019 | IoU: 0.2799
# [Train] Epoch 28/100 | Total: 2.9864 | BCE: 1.7155 | Dice: 0.4293 | IoU: 0.2997
# [Train] Epoch 28/100 | Total: 2.8835 | BCE: 1.6354 | Dice: 0.4435 | IoU: 0.3085
# [Train] Epoch 28/100 | Total: 2.9363 | BCE: 1.7623 | Dice: 0.4803 | IoU: 0.3457
# [Train] Epoch 28/100 | Total: 3.2013 | BCE: 1.9294 | Dice: 0.4277 | IoU: 0.3005
# [Train] Epoch 28/100 | Total: 2.8507 | BCE: 1.6280 | Dice: 0.4571 | IoU: 0.3201
# [Train] Epoch 28/100 | Total: 2.8192 | BCE: 1.6167 | Dice: 0.4685 | IoU: 0.3290
# [Train] Epoch 28/100 | Total: 2.9569 | BCE: 1.7332 | Dice: 0.4561 | IoU: 0.3202
# [Train] Epoch 28/100 | Total: 3.1620 | BCE: 1.8800 | Dice: 0.4236 | IoU: 0.2944
# [Train] Epoch 28/100 | Total: 2.8606 | BCE: 1.6656 | Dice: 0.4749 | IoU: 0.3301
# [Train] Epoch 28/100 | Total: 3.0549 | BCE: 1.8294 | Dice: 0.4535 | IoU: 0.3210
# [Train] Epoch 28/100 | Total: 3.0141 | BCE: 1.7285 | Dice: 0.4207 | IoU: 0.2937
# [Train] Epoch 28/100 | Total: 3.0010 | BCE: 1.8049 | Dice: 0.4714 | IoU: 0.3325
# [Val] Epoch 28 | BCE Loss: 0.3591 | Dice: 0.4814 | IoU: 0.3447
# [Val] Epoch 28 | BCE Loss: 0.3261 | Dice: 0.5039 | IoU: 0.3662
# [Val] Epoch 28 | BCE Loss: 0.3817 | Dice: 0.5352 | IoU: 0.4028
# [Val] Epoch 28 | BCE Loss: 0.3305 | Dice: 0.3892 | IoU: 0.2584
# ==> Epoch 28
#     Train Total Loss : 2.9792 | BCE: 1.7395 | Dice score: 0.4468 | IoU score: 0.3135
#     Val   BCE Loss   : 0.3494 | Dice score: 0.4774 | IoU score : 0.3430
# [Train] Epoch 29/100 | Total: 2.8637 | BCE: 1.5497 | Dice: 0.4064 | IoU: 0.2796
# [Train] Epoch 29/100 | Total: 2.7473 | BCE: 1.4711 | Dice: 0.4256 | IoU: 0.2983
# [Train] Epoch 29/100 | Total: 2.7595 | BCE: 1.5658 | Dice: 0.4723 | IoU: 0.3339
# [Train] Epoch 29/100 | Total: 2.8530 | BCE: 1.6314 | Dice: 0.4551 | IoU: 0.3232
# [Train] Epoch 29/100 | Total: 3.0363 | BCE: 1.8985 | Dice: 0.5022 | IoU: 0.3600
# [Train] Epoch 29/100 | Total: 3.0590 | BCE: 1.8879 | Dice: 0.4799 | IoU: 0.3491
# [Train] Epoch 29/100 | Total: 3.1746 | BCE: 1.9177 | Dice: 0.4372 | IoU: 0.3059
# [Train] Epoch 29/100 | Total: 2.9974 | BCE: 1.7944 | Dice: 0.4638 | IoU: 0.3331
# [Train] Epoch 29/100 | Total: 3.1297 | BCE: 1.8724 | Dice: 0.4384 | IoU: 0.3042
# [Train] Epoch 29/100 | Total: 2.9708 | BCE: 1.7326 | Dice: 0.4510 | IoU: 0.3108
# [Train] Epoch 29/100 | Total: 3.2093 | BCE: 1.8906 | Dice: 0.4046 | IoU: 0.2767
# [Train] Epoch 29/100 | Total: 3.0646 | BCE: 1.6842 | Dice: 0.3740 | IoU: 0.2455
# [Train] Epoch 29/100 | Total: 3.1188 | BCE: 1.7513 | Dice: 0.3796 | IoU: 0.2529
# [Val] Epoch 29 | BCE Loss: 0.3313 | Dice: 0.4813 | IoU: 0.3410
# [Val] Epoch 29 | BCE Loss: 0.3035 | Dice: 0.5125 | IoU: 0.3744
# [Val] Epoch 29 | BCE Loss: 0.3431 | Dice: 0.5305 | IoU: 0.3986
# [Val] Epoch 29 | BCE Loss: 0.2907 | Dice: 0.4302 | IoU: 0.2966
# ==> Epoch 29
#     Train Total Loss : 2.9988 | BCE: 1.7421 | Dice score: 0.4377 | IoU score: 0.3056
#     Val   BCE Loss   : 0.3171 | Dice score: 0.4886 | IoU score : 0.3526
# [Train] Epoch 30/100 | Total: 3.2980 | BCE: 1.9769 | Dice: 0.4051 | IoU: 0.2739
# [Train] Epoch 30/100 | Total: 3.0119 | BCE: 1.8033 | Dice: 0.4649 | IoU: 0.3265
# [Train] Epoch 30/100 | Total: 3.0090 | BCE: 1.7684 | Dice: 0.4493 | IoU: 0.3101
# [Train] Epoch 30/100 | Total: 3.0823 | BCE: 1.8186 | Dice: 0.4312 | IoU: 0.3051
# [Train] Epoch 30/100 | Total: 2.9497 | BCE: 1.6699 | Dice: 0.4247 | IoU: 0.2954
# [Train] Epoch 30/100 | Total: 2.8610 | BCE: 1.6491 | Dice: 0.4631 | IoU: 0.3250
# [Train] Epoch 30/100 | Total: 2.9373 | BCE: 1.6632 | Dice: 0.4295 | IoU: 0.2964
# [Train] Epoch 30/100 | Total: 2.7770 | BCE: 1.4642 | Dice: 0.4072 | IoU: 0.2801
# [Train] Epoch 30/100 | Total: 3.0571 | BCE: 1.8017 | Dice: 0.4378 | IoU: 0.3068
# [Train] Epoch 30/100 | Total: 3.0192 | BCE: 1.6982 | Dice: 0.4038 | IoU: 0.2753
# [Train] Epoch 30/100 | Total: 2.8873 | BCE: 1.5720 | Dice: 0.4064 | IoU: 0.2783
# [Train] Epoch 30/100 | Total: 2.9981 | BCE: 1.7639 | Dice: 0.4487 | IoU: 0.3171
# [Train] Epoch 30/100 | Total: 3.1107 | BCE: 1.8147 | Dice: 0.4205 | IoU: 0.2836
# [Val] Epoch 30 | BCE Loss: 0.4288 | Dice: 0.4699 | IoU: 0.3314
# [Val] Epoch 30 | BCE Loss: 0.3860 | Dice: 0.4820 | IoU: 0.3465
# [Val] Epoch 30 | BCE Loss: 0.4277 | Dice: 0.5244 | IoU: 0.3884
# [Val] Epoch 30 | BCE Loss: 0.3777 | Dice: 0.3952 | IoU: 0.2730
# ==> Epoch 30
#     Train Total Loss : 2.9999 | BCE: 1.7280 | Dice score: 0.4302 | IoU score: 0.2980
#     Val   BCE Loss   : 0.4051 | Dice score: 0.4679 | IoU score : 0.3348
# [Train] Epoch 31/100 | Total: 3.0150 | BCE: 1.8038 | Dice: 0.4643 | IoU: 0.3245
# [Train] Epoch 31/100 | Total: 3.0331 | BCE: 1.7308 | Dice: 0.4154 | IoU: 0.2823
# [Train] Epoch 31/100 | Total: 2.8369 | BCE: 1.5809 | Dice: 0.4372 | IoU: 0.3068
# [Train] Epoch 31/100 | Total: 2.8928 | BCE: 1.5840 | Dice: 0.4089 | IoU: 0.2823
# [Train] Epoch 31/100 | Total: 2.9397 | BCE: 1.6861 | Dice: 0.4407 | IoU: 0.3057
# [Train] Epoch 31/100 | Total: 2.9816 | BCE: 1.6503 | Dice: 0.3999 | IoU: 0.2687
# [Train] Epoch 31/100 | Total: 3.0517 | BCE: 1.8602 | Dice: 0.4736 | IoU: 0.3349
# [Train] Epoch 31/100 | Total: 2.7725 | BCE: 1.5420 | Dice: 0.4535 | IoU: 0.3159
# [Train] Epoch 31/100 | Total: 2.8139 | BCE: 1.6500 | Dice: 0.4852 | IoU: 0.3508
# [Train] Epoch 31/100 | Total: 2.8774 | BCE: 1.6573 | Dice: 0.4547 | IoU: 0.3252
# [Train] Epoch 31/100 | Total: 2.9629 | BCE: 1.7203 | Dice: 0.4442 | IoU: 0.3133
# [Train] Epoch 31/100 | Total: 2.9048 | BCE: 1.6788 | Dice: 0.4505 | IoU: 0.3234
# [Train] Epoch 31/100 | Total: 2.9717 | BCE: 1.7434 | Dice: 0.4540 | IoU: 0.3177
# [Val] Epoch 31 | BCE Loss: 0.3279 | Dice: 0.4229 | IoU: 0.3042
# [Val] Epoch 31 | BCE Loss: 0.2965 | Dice: 0.4994 | IoU: 0.3696
# [Val] Epoch 31 | BCE Loss: 0.3860 | Dice: 0.4590 | IoU: 0.3393
# [Val] Epoch 31 | BCE Loss: 0.2468 | Dice: 0.3283 | IoU: 0.2208
# ==> Epoch 31
#     Train Total Loss : 2.9272 | BCE: 1.6837 | Dice score: 0.4448 | IoU score: 0.3117
#     Val   BCE Loss   : 0.3143 | Dice score: 0.4274 | IoU score : 0.3085
# [Train] Epoch 32/100 | Total: 2.9816 | BCE: 1.7198 | Dice: 0.4316 | IoU: 0.3066
# [Train] Epoch 32/100 | Total: 2.8834 | BCE: 1.6366 | Dice: 0.4419 | IoU: 0.3112
# [Train] Epoch 32/100 | Total: 3.2481 | BCE: 1.9128 | Dice: 0.3949 | IoU: 0.2699
# [Train] Epoch 32/100 | Total: 2.9335 | BCE: 1.6639 | Dice: 0.4274 | IoU: 0.3030
# [Train] Epoch 32/100 | Total: 2.9137 | BCE: 1.7062 | Dice: 0.4661 | IoU: 0.3264
# [Train] Epoch 32/100 | Total: 2.9261 | BCE: 1.6947 | Dice: 0.4504 | IoU: 0.3182
# [Train] Epoch 32/100 | Total: 3.2010 | BCE: 1.8250 | Dice: 0.3751 | IoU: 0.2490
# [Train] Epoch 32/100 | Total: 3.0044 | BCE: 1.8008 | Dice: 0.4659 | IoU: 0.3305
# [Train] Epoch 32/100 | Total: 2.6788 | BCE: 1.4882 | Dice: 0.4737 | IoU: 0.3357
# [Train] Epoch 32/100 | Total: 2.9038 | BCE: 1.7348 | Dice: 0.4882 | IoU: 0.3428
# [Train] Epoch 32/100 | Total: 2.7067 | BCE: 1.4722 | Dice: 0.4522 | IoU: 0.3134
# [Train] Epoch 32/100 | Total: 2.7393 | BCE: 1.5511 | Dice: 0.4759 | IoU: 0.3359
# [Train] Epoch 32/100 | Total: 2.6814 | BCE: 1.4575 | Dice: 0.4570 | IoU: 0.3191
# [Val] Epoch 32 | BCE Loss: 0.3876 | Dice: 0.4736 | IoU: 0.3374
# [Val] Epoch 32 | BCE Loss: 0.3323 | Dice: 0.5095 | IoU: 0.3718
# [Val] Epoch 32 | BCE Loss: 0.3807 | Dice: 0.5346 | IoU: 0.3995
# [Val] Epoch 32 | BCE Loss: 0.3610 | Dice: 0.3637 | IoU: 0.2464
# ==> Epoch 32
#     Train Total Loss : 2.9078 | BCE: 1.6664 | Dice score: 0.4462 | IoU score: 0.3124
# ...
# [Train] Epoch 89/100 | Total: 2.3065 | BCE: 1.3140 | Dice: 0.5728 | IoU: 0.4347
# [Train] Epoch 89/100 | Total: 2.3660 | BCE: 1.3657 | Dice: 0.5685 | IoU: 0.4312
# [Train] Epoch 89/100 | Total: 2.0096 | BCE: 1.0148 | Dice: 0.5724 | IoU: 0.4329
# [Train] Epoch 89/100 | Total: 2.0645 | BCE: 1.1262 | Dice: 0.6018 | IoU: 0.4599
# [Train] Epoch 89/100 | Total: 1.9824 | BCE: 1.0322 | Dice: 0.5931 | IoU: 0.4567
# [Train] Epoch 89/100 | Total: 2.4038 | BCE: 1.3176 | Dice: 0.5227 | IoU: 0.3911
# [Train] Epoch 89/100 | Total: 2.1390 | BCE: 1.1408 | Dice: 0.5674 | IoU: 0.4344
# [Train] Epoch 89/100 | Total: 2.1365 | BCE: 1.1434 | Dice: 0.5697 | IoU: 0.4372
# [Train] Epoch 89/100 | Total: 2.2179 | BCE: 1.2160 | Dice: 0.5664 | IoU: 0.4317
# [Train] Epoch 89/100 | Total: 1.8526 | BCE: 0.9854 | Dice: 0.6356 | IoU: 0.4972
# [Train] Epoch 89/100 | Total: 2.2567 | BCE: 1.3304 | Dice: 0.6060 | IoU: 0.4676
# [Val] Epoch 89 | BCE Loss: 0.4180 | Dice: 0.5428 | IoU: 0.4066
# [Val] Epoch 89 | BCE Loss: 0.3585 | Dice: 0.5830 | IoU: 0.4450
# [Val] Epoch 89 | BCE Loss: 0.3255 | Dice: 0.6436 | IoU: 0.5111
# [Val] Epoch 89 | BCE Loss: 0.3115 | Dice: 0.4510 | IoU: 0.3321
# ==> Epoch 89
#     Train Total Loss : 2.1726 | BCE: 1.1917 | Dice score: 0.5774 | IoU score: 0.4417
#     Val   BCE Loss   : 0.3534 | Dice score: 0.5551 | IoU score : 0.4237
# [Train] Epoch 90/100 | Total: 2.2326 | BCE: 1.2865 | Dice: 0.5943 | IoU: 0.4596
# [Train] Epoch 90/100 | Total: 2.1473 | BCE: 1.2014 | Dice: 0.5943 | IoU: 0.4599
# [Train] Epoch 90/100 | Total: 2.2284 | BCE: 1.2408 | Dice: 0.5736 | IoU: 0.4388
# [Train] Epoch 90/100 | Total: 2.2167 | BCE: 1.1769 | Dice: 0.5472 | IoU: 0.4130
# [Train] Epoch 90/100 | Total: 2.3519 | BCE: 1.2838 | Dice: 0.5324 | IoU: 0.3995
# [Train] Epoch 90/100 | Total: 2.2557 | BCE: 1.1549 | Dice: 0.5146 | IoU: 0.3847
# [Train] Epoch 90/100 | Total: 2.1674 | BCE: 1.0852 | Dice: 0.5197 | IoU: 0.3981
# [Train] Epoch 90/100 | Total: 2.1009 | BCE: 1.1428 | Dice: 0.5911 | IoU: 0.4509
# [Train] Epoch 90/100 | Total: 2.1523 | BCE: 1.1136 | Dice: 0.5466 | IoU: 0.4147
# [Train] Epoch 90/100 | Total: 2.0399 | BCE: 1.1075 | Dice: 0.6048 | IoU: 0.4628
# [Train] Epoch 90/100 | Total: 1.9897 | BCE: 1.0829 | Dice: 0.6150 | IoU: 0.4782
# [Train] Epoch 90/100 | Total: 2.1595 | BCE: 1.2074 | Dice: 0.5949 | IoU: 0.4530
# [Train] Epoch 90/100 | Total: 2.2120 | BCE: 1.2083 | Dice: 0.5684 | IoU: 0.4279
# [Val] Epoch 90 | BCE Loss: 0.4031 | Dice: 0.5433 | IoU: 0.4114
# [Val] Epoch 90 | BCE Loss: 0.3475 | Dice: 0.5920 | IoU: 0.4568
# [Val] Epoch 90 | BCE Loss: 0.3380 | Dice: 0.6578 | IoU: 0.5248
# [Val] Epoch 90 | BCE Loss: 0.2429 | Dice: 0.5345 | IoU: 0.3892
# ==> Epoch 90
#     Train Total Loss : 2.1734 | BCE: 1.1763 | Dice score: 0.5690 | IoU score: 0.4339
#     Val   BCE Loss   : 0.3329 | Dice score: 0.5819 | IoU score : 0.4456
# [Train] Epoch 91/100 | Total: 2.0041 | BCE: 1.0716 | Dice: 0.6031 | IoU: 0.4643
# [Train] Epoch 91/100 | Total: 2.2474 | BCE: 1.2193 | Dice: 0.5533 | IoU: 0.4186
# [Train] Epoch 91/100 | Total: 2.0971 | BCE: 1.1988 | Dice: 0.6207 | IoU: 0.4810
# [Train] Epoch 91/100 | Total: 2.0242 | BCE: 0.9807 | Dice: 0.5460 | IoU: 0.4104
# [Train] Epoch 91/100 | Total: 2.3114 | BCE: 1.3244 | Dice: 0.5744 | IoU: 0.4386
# [Train] Epoch 91/100 | Total: 2.1320 | BCE: 1.1570 | Dice: 0.5778 | IoU: 0.4472
# [Train] Epoch 91/100 | Total: 1.9844 | BCE: 1.0689 | Dice: 0.6126 | IoU: 0.4719
# [Train] Epoch 91/100 | Total: 2.1390 | BCE: 1.0896 | Dice: 0.5388 | IoU: 0.4118
# [Train] Epoch 91/100 | Total: 2.0468 | BCE: 1.0350 | Dice: 0.5614 | IoU: 0.4267
# [Train] Epoch 91/100 | Total: 2.3695 | BCE: 1.3850 | Dice: 0.5745 | IoU: 0.4410
# [Train] Epoch 91/100 | Total: 2.3322 | BCE: 1.3114 | Dice: 0.5594 | IoU: 0.4199
# [Train] Epoch 91/100 | Total: 2.1142 | BCE: 1.2295 | Dice: 0.6253 | IoU: 0.4900
# [Train] Epoch 91/100 | Total: 2.3889 | BCE: 1.3877 | Dice: 0.5700 | IoU: 0.4288
# [Val] Epoch 91 | BCE Loss: 0.3454 | Dice: 0.5405 | IoU: 0.4090
# [Val] Epoch 91 | BCE Loss: 0.3306 | Dice: 0.5775 | IoU: 0.4483
# [Val] Epoch 91 | BCE Loss: 0.3194 | Dice: 0.6280 | IoU: 0.4935
# [Val] Epoch 91 | BCE Loss: 0.2164 | Dice: 0.5044 | IoU: 0.3823
# ==> Epoch 91
#     Train Total Loss : 2.1686 | BCE: 1.1891 | Dice score: 0.5783 | IoU score: 0.4423
#     Val   BCE Loss   : 0.3030 | Dice score: 0.5626 | IoU score : 0.4333
# [Train] Epoch 92/100 | Total: 2.1398 | BCE: 1.1192 | Dice: 0.5600 | IoU: 0.4193
# [Train] Epoch 92/100 | Total: 2.2169 | BCE: 1.1563 | Dice: 0.5343 | IoU: 0.4051
# [Train] Epoch 92/100 | Total: 1.8877 | BCE: 0.9840 | Dice: 0.6166 | IoU: 0.4797
# [Train] Epoch 92/100 | Total: 2.1769 | BCE: 1.1484 | Dice: 0.5511 | IoU: 0.4204
# [Train] Epoch 92/100 | Total: 2.4498 | BCE: 1.3885 | Dice: 0.5356 | IoU: 0.4032
# [Train] Epoch 92/100 | Total: 2.0033 | BCE: 1.0985 | Dice: 0.6168 | IoU: 0.4785
# [Train] Epoch 92/100 | Total: 2.1741 | BCE: 1.1402 | Dice: 0.5480 | IoU: 0.4181
# [Train] Epoch 92/100 | Total: 2.1183 | BCE: 1.1476 | Dice: 0.5806 | IoU: 0.4487
# [Train] Epoch 92/100 | Total: 2.1503 | BCE: 1.2253 | Dice: 0.6055 | IoU: 0.4695
# [Train] Epoch 92/100 | Total: 2.1598 | BCE: 1.2006 | Dice: 0.5882 | IoU: 0.4526
# [Train] Epoch 92/100 | Total: 2.0733 | BCE: 1.1772 | Dice: 0.6232 | IoU: 0.4806
# [Train] Epoch 92/100 | Total: 2.3355 | BCE: 1.3428 | Dice: 0.5711 | IoU: 0.4362
# [Train] Epoch 92/100 | Total: 2.3273 | BCE: 1.2884 | Dice: 0.5488 | IoU: 0.4123
# [Val] Epoch 92 | BCE Loss: 0.3275 | Dice: 0.5411 | IoU: 0.4058
# [Val] Epoch 92 | BCE Loss: 0.3039 | Dice: 0.5658 | IoU: 0.4357
# [Val] Epoch 92 | BCE Loss: 0.3426 | Dice: 0.6124 | IoU: 0.4773
# [Val] Epoch 92 | BCE Loss: 0.2390 | Dice: 0.4725 | IoU: 0.3473
# ==> Epoch 92
#     Train Total Loss : 2.1702 | BCE: 1.1859 | Dice score: 0.5754 | IoU score: 0.4403
#     Val   BCE Loss   : 0.3033 | Dice score: 0.5479 | IoU score : 0.4165
# [Train] Epoch 93/100 | Total: 2.2164 | BCE: 1.1857 | Dice: 0.5559 | IoU: 0.4135
# [Train] Epoch 93/100 | Total: 2.0282 | BCE: 1.0528 | Dice: 0.5776 | IoU: 0.4470
# [Train] Epoch 93/100 | Total: 2.1178 | BCE: 1.1154 | Dice: 0.5691 | IoU: 0.4285
# [Train] Epoch 93/100 | Total: 2.2714 | BCE: 1.2316 | Dice: 0.5489 | IoU: 0.4112
# [Train] Epoch 93/100 | Total: 2.0754 | BCE: 1.0799 | Dice: 0.5688 | IoU: 0.4357
# [Train] Epoch 93/100 | Total: 2.0245 | BCE: 1.1301 | Dice: 0.6226 | IoU: 0.4829
# [Train] Epoch 93/100 | Total: 2.0636 | BCE: 1.1281 | Dice: 0.6013 | IoU: 0.4632
# [Train] Epoch 93/100 | Total: 2.0376 | BCE: 1.0733 | Dice: 0.5852 | IoU: 0.4506
# [Train] Epoch 93/100 | Total: 2.2878 | BCE: 1.3236 | Dice: 0.5787 | IoU: 0.4571
# [Train] Epoch 93/100 | Total: 1.9657 | BCE: 1.0617 | Dice: 0.6156 | IoU: 0.4804
# [Train] Epoch 93/100 | Total: 2.1403 | BCE: 1.1411 | Dice: 0.5713 | IoU: 0.4295
# [Train] Epoch 93/100 | Total: 2.4085 | BCE: 1.4586 | Dice: 0.5965 | IoU: 0.4536
# [Train] Epoch 93/100 | Total: 2.0704 | BCE: 1.1094 | Dice: 0.5869 | IoU: 0.4521
# [Val] Epoch 93 | BCE Loss: 0.4123 | Dice: 0.5340 | IoU: 0.4077
# [Val] Epoch 93 | BCE Loss: 0.3635 | Dice: 0.6107 | IoU: 0.4740
# [Val] Epoch 93 | BCE Loss: 0.3654 | Dice: 0.6421 | IoU: 0.5108
# [Val] Epoch 93 | BCE Loss: 0.2375 | Dice: 0.5479 | IoU: 0.4042
# ==> Epoch 93
#     Train Total Loss : 2.1314 | BCE: 1.1609 | Dice score: 0.5830 | IoU score: 0.4466
#     Val   BCE Loss   : 0.3447 | Dice score: 0.5837 | IoU score : 0.4492
# [Train] Epoch 94/100 | Total: 2.3510 | BCE: 1.3070 | Dice: 0.5436 | IoU: 0.4124
# [Train] Epoch 94/100 | Total: 2.1675 | BCE: 1.2141 | Dice: 0.5926 | IoU: 0.4540
# [Train] Epoch 94/100 | Total: 2.1142 | BCE: 1.0577 | Dice: 0.5415 | IoU: 0.4019
# [Train] Epoch 94/100 | Total: 2.3514 | BCE: 1.3374 | Dice: 0.5603 | IoU: 0.4258
# [Train] Epoch 94/100 | Total: 2.2047 | BCE: 1.2164 | Dice: 0.5755 | IoU: 0.4362
# [Train] Epoch 94/100 | Total: 2.1866 | BCE: 1.0933 | Dice: 0.5208 | IoU: 0.3859
# [Train] Epoch 94/100 | Total: 2.2772 | BCE: 1.2243 | Dice: 0.5415 | IoU: 0.4057
# [Train] Epoch 94/100 | Total: 2.0854 | BCE: 1.0497 | Dice: 0.5452 | IoU: 0.4192
# [Train] Epoch 94/100 | Total: 2.1931 | BCE: 1.2122 | Dice: 0.5823 | IoU: 0.4368
# [Train] Epoch 94/100 | Total: 1.9202 | BCE: 1.0022 | Dice: 0.6075 | IoU: 0.4745
# [Train] Epoch 94/100 | Total: 2.1008 | BCE: 1.1725 | Dice: 0.6047 | IoU: 0.4670
# [Train] Epoch 94/100 | Total: 2.2667 | BCE: 1.2653 | Dice: 0.5626 | IoU: 0.4360
# [Train] Epoch 94/100 | Total: 2.2974 | BCE: 1.2822 | Dice: 0.5579 | IoU: 0.4268
# [Val] Epoch 94 | BCE Loss: 0.3824 | Dice: 0.5265 | IoU: 0.4023
# [Val] Epoch 94 | BCE Loss: 0.3297 | Dice: 0.6170 | IoU: 0.4790
# [Val] Epoch 94 | BCE Loss: 0.3425 | Dice: 0.6356 | IoU: 0.5026
# [Val] Epoch 94 | BCE Loss: 0.2433 | Dice: 0.4842 | IoU: 0.3658
# ==> Epoch 94
#     Train Total Loss : 2.1936 | BCE: 1.1873 | Dice score: 0.5643 | IoU score: 0.4294
#     Val   BCE Loss   : 0.3245 | Dice score: 0.5658 | IoU score : 0.4374
# [Train] Epoch 95/100 | Total: 2.0638 | BCE: 1.1657 | Dice: 0.6195 | IoU: 0.4824
# [Train] Epoch 95/100 | Total: 2.4162 | BCE: 1.3908 | Dice: 0.5566 | IoU: 0.4180
# [Train] Epoch 95/100 | Total: 2.3094 | BCE: 1.2492 | Dice: 0.5379 | IoU: 0.4020
# [Train] Epoch 95/100 | Total: 2.2535 | BCE: 1.1980 | Dice: 0.5425 | IoU: 0.4020
# [Train] Epoch 95/100 | Total: 2.2382 | BCE: 1.2481 | Dice: 0.5734 | IoU: 0.4366
# [Train] Epoch 95/100 | Total: 1.9197 | BCE: 0.9987 | Dice: 0.6114 | IoU: 0.4676
# [Train] Epoch 95/100 | Total: 2.0552 | BCE: 1.0158 | Dice: 0.5452 | IoU: 0.4155
# [Train] Epoch 95/100 | Total: 2.3390 | BCE: 1.3036 | Dice: 0.5498 | IoU: 0.4147
# [Train] Epoch 95/100 | Total: 2.3360 | BCE: 1.2769 | Dice: 0.5385 | IoU: 0.4025
# [Train] Epoch 95/100 | Total: 2.1553 | BCE: 1.1934 | Dice: 0.5882 | IoU: 0.4499
# [Train] Epoch 95/100 | Total: 2.1126 | BCE: 1.0621 | Dice: 0.5397 | IoU: 0.4097
# [Train] Epoch 95/100 | Total: 2.0837 | BCE: 1.1879 | Dice: 0.6179 | IoU: 0.4864
# [Train] Epoch 95/100 | Total: 1.8994 | BCE: 0.9987 | Dice: 0.6140 | IoU: 0.4853
# [Val] Epoch 95 | BCE Loss: 0.4043 | Dice: 0.5412 | IoU: 0.4064
# [Val] Epoch 95 | BCE Loss: 0.3254 | Dice: 0.6124 | IoU: 0.4785
# [Val] Epoch 95 | BCE Loss: 0.3517 | Dice: 0.6404 | IoU: 0.5048
# [Val] Epoch 95 | BCE Loss: 0.2384 | Dice: 0.5301 | IoU: 0.3908
# ==> Epoch 95
#     Train Total Loss : 2.1679 | BCE: 1.1761 | Dice score: 0.5719 | IoU score: 0.4363
#     Val   BCE Loss   : 0.3299 | Dice score: 0.5810 | IoU score : 0.4451
# [Train] Epoch 96/100 | Total: 2.2082 | BCE: 1.1717 | Dice: 0.5495 | IoU: 0.4141
# [Train] Epoch 96/100 | Total: 2.0122 | BCE: 1.0159 | Dice: 0.5650 | IoU: 0.4387
# [Train] Epoch 96/100 | Total: 2.3493 | BCE: 1.2839 | Dice: 0.5290 | IoU: 0.4056
# [Train] Epoch 96/100 | Total: 2.2044 | BCE: 1.2413 | Dice: 0.5880 | IoU: 0.4490
# [Train] Epoch 96/100 | Total: 1.8391 | BCE: 1.0067 | Dice: 0.6524 | IoU: 0.5151
# [Train] Epoch 96/100 | Total: 2.1884 | BCE: 1.2111 | Dice: 0.5763 | IoU: 0.4464
# [Train] Epoch 96/100 | Total: 2.0889 | BCE: 1.1368 | Dice: 0.5912 | IoU: 0.4567
# [Train] Epoch 96/100 | Total: 2.0419 | BCE: 1.0721 | Dice: 0.5827 | IoU: 0.4474
# [Train] Epoch 96/100 | Total: 2.3940 | BCE: 1.4233 | Dice: 0.5806 | IoU: 0.4486
# [Train] Epoch 96/100 | Total: 2.3942 | BCE: 1.3272 | Dice: 0.5336 | IoU: 0.3994
# [Train] Epoch 96/100 | Total: 2.0360 | BCE: 1.0987 | Dice: 0.6043 | IoU: 0.4584
# [Train] Epoch 96/100 | Total: 2.4269 | BCE: 1.3565 | Dice: 0.5306 | IoU: 0.3991
# [Train] Epoch 96/100 | Total: 1.9320 | BCE: 1.0021 | Dice: 0.6027 | IoU: 0.4675
# [Val] Epoch 96 | BCE Loss: 0.3641 | Dice: 0.5442 | IoU: 0.4108
# [Val] Epoch 96 | BCE Loss: 0.3107 | Dice: 0.6013 | IoU: 0.4650
# [Val] Epoch 96 | BCE Loss: 0.2972 | Dice: 0.6483 | IoU: 0.5102
# [Val] Epoch 96 | BCE Loss: 0.2626 | Dice: 0.4589 | IoU: 0.3403
# ==> Epoch 96
#     Train Total Loss : 2.1627 | BCE: 1.1806 | Dice score: 0.5758 | IoU score: 0.4420
#     Val   BCE Loss   : 0.3086 | Dice score: 0.5631 | IoU score : 0.4316
# [Train] Epoch 97/100 | Total: 2.0851 | BCE: 1.1069 | Dice: 0.5783 | IoU: 0.4435
# [Train] Epoch 97/100 | Total: 2.2298 | BCE: 1.1493 | Dice: 0.5244 | IoU: 0.3950
# [Train] Epoch 97/100 | Total: 2.2065 | BCE: 1.1983 | Dice: 0.5621 | IoU: 0.4297
# [Train] Epoch 97/100 | Total: 2.1612 | BCE: 1.1662 | Dice: 0.5681 | IoU: 0.4369
# [Train] Epoch 97/100 | Total: 2.3085 | BCE: 1.3028 | Dice: 0.5676 | IoU: 0.4267
# [Train] Epoch 97/100 | Total: 2.1946 | BCE: 1.2130 | Dice: 0.5775 | IoU: 0.4408
# [Train] Epoch 97/100 | Total: 2.0029 | BCE: 1.0708 | Dice: 0.6044 | IoU: 0.4636
# [Train] Epoch 97/100 | Total: 2.3344 | BCE: 1.3778 | Dice: 0.5922 | IoU: 0.4512
# [Train] Epoch 97/100 | Total: 2.2800 | BCE: 1.2300 | Dice: 0.5402 | IoU: 0.4097
# [Train] Epoch 97/100 | Total: 2.0151 | BCE: 1.0682 | Dice: 0.5940 | IoU: 0.4592
# [Train] Epoch 97/100 | Total: 2.3637 | BCE: 1.3215 | Dice: 0.5441 | IoU: 0.4137
# [Train] Epoch 97/100 | Total: 2.1602 | BCE: 1.1848 | Dice: 0.5780 | IoU: 0.4465
# [Train] Epoch 97/100 | Total: 2.0705 | BCE: 1.1499 | Dice: 0.6168 | IoU: 0.4625
# [Val] Epoch 97 | BCE Loss: 0.3636 | Dice: 0.5461 | IoU: 0.4130
# [Val] Epoch 97 | BCE Loss: 0.3346 | Dice: 0.5955 | IoU: 0.4565
# [Val] Epoch 97 | BCE Loss: 0.3497 | Dice: 0.6347 | IoU: 0.5000
# [Val] Epoch 97 | BCE Loss: 0.2679 | Dice: 0.4680 | IoU: 0.3509
# ==> Epoch 97
#     Train Total Loss : 2.1856 | BCE: 1.1953 | Dice score: 0.5729 | IoU score: 0.4369
#     Val   BCE Loss   : 0.3289 | Dice score: 0.5611 | IoU score : 0.4301
# [Train] Epoch 98/100 | Total: 2.1949 | BCE: 1.0958 | Dice: 0.5133 | IoU: 0.3875
# [Train] Epoch 98/100 | Total: 2.1309 | BCE: 1.1216 | Dice: 0.5577 | IoU: 0.4330
# [Train] Epoch 98/100 | Total: 1.8346 | BCE: 0.9799 | Dice: 0.6417 | IoU: 0.5036
# [Train] Epoch 98/100 | Total: 2.2925 | BCE: 1.2507 | Dice: 0.5455 | IoU: 0.4126
# [Train] Epoch 98/100 | Total: 2.2337 | BCE: 1.3330 | Dice: 0.6174 | IoU: 0.4819
# [Train] Epoch 98/100 | Total: 2.2494 | BCE: 1.2106 | Dice: 0.5479 | IoU: 0.4132
# [Train] Epoch 98/100 | Total: 1.9806 | BCE: 1.1032 | Dice: 0.6322 | IoU: 0.4903
# [Train] Epoch 98/100 | Total: 2.0481 | BCE: 1.1252 | Dice: 0.6089 | IoU: 0.4682
# [Train] Epoch 98/100 | Total: 2.1756 | BCE: 1.2652 | Dice: 0.6116 | IoU: 0.4780
# [Train] Epoch 98/100 | Total: 2.2216 | BCE: 1.2110 | Dice: 0.5585 | IoU: 0.4309
# [Train] Epoch 98/100 | Total: 2.0491 | BCE: 1.0857 | Dice: 0.5882 | IoU: 0.4484
# [Train] Epoch 98/100 | Total: 2.0691 | BCE: 1.0287 | Dice: 0.5438 | IoU: 0.4159
# [Train] Epoch 98/100 | Total: 1.8128 | BCE: 0.9585 | Dice: 0.6415 | IoU: 0.5042
# [Val] Epoch 98 | BCE Loss: 0.3123 | Dice: 0.5844 | IoU: 0.4520
# [Val] Epoch 98 | BCE Loss: 0.3348 | Dice: 0.6021 | IoU: 0.4678
# [Val] Epoch 98 | BCE Loss: 0.3281 | Dice: 0.6471 | IoU: 0.5151
# [Val] Epoch 98 | BCE Loss: 0.2598 | Dice: 0.4304 | IoU: 0.3162
# ==> Epoch 98
#     Train Total Loss : 2.0994 | BCE: 1.1361 | Dice score: 0.5853 | IoU score: 0.4514
#     Val   BCE Loss   : 0.3088 | Dice score: 0.5660 | IoU score : 0.4378
# [Train] Epoch 99/100 | Total: 2.1862 | BCE: 1.2480 | Dice: 0.5987 | IoU: 0.4630
# [Train] Epoch 99/100 | Total: 2.1606 | BCE: 1.1963 | Dice: 0.5864 | IoU: 0.4493
# [Train] Epoch 99/100 | Total: 2.3266 | BCE: 1.2775 | Dice: 0.5394 | IoU: 0.4114
# [Train] Epoch 99/100 | Total: 2.1334 | BCE: 1.1846 | Dice: 0.5947 | IoU: 0.4564
# [Train] Epoch 99/100 | Total: 2.0172 | BCE: 1.1286 | Dice: 0.6242 | IoU: 0.4871
# [Train] Epoch 99/100 | Total: 1.9707 | BCE: 1.0656 | Dice: 0.6158 | IoU: 0.4791
# [Train] Epoch 99/100 | Total: 2.2552 | BCE: 1.2489 | Dice: 0.5629 | IoU: 0.4308
# [Train] Epoch 99/100 | Total: 2.1311 | BCE: 1.1995 | Dice: 0.6020 | IoU: 0.4664
# [Train] Epoch 99/100 | Total: 2.0757 | BCE: 1.1046 | Dice: 0.5816 | IoU: 0.4473
# [Train] Epoch 99/100 | Total: 1.9003 | BCE: 1.0011 | Dice: 0.6147 | IoU: 0.4861
# [Train] Epoch 99/100 | Total: 2.3440 | BCE: 1.3047 | Dice: 0.5475 | IoU: 0.4132
# [Train] Epoch 99/100 | Total: 2.0492 | BCE: 1.0273 | Dice: 0.5570 | IoU: 0.4211
# [Train] Epoch 99/100 | Total: 2.0876 | BCE: 1.1050 | Dice: 0.5758 | IoU: 0.4415
# [Val] Epoch 99 | BCE Loss: 0.3319 | Dice: 0.4970 | IoU: 0.3739
# [Val] Epoch 99 | BCE Loss: 0.2971 | Dice: 0.5753 | IoU: 0.4457
# [Val] Epoch 99 | BCE Loss: 0.3652 | Dice: 0.5988 | IoU: 0.4705
# [Val] Epoch 99 | BCE Loss: 0.1747 | Dice: 0.5001 | IoU: 0.3833
# ==> Epoch 99
#     Train Total Loss : 2.1260 | BCE: 1.1609 | Dice score: 0.5847 | IoU score: 0.4502
#     Val   BCE Loss   : 0.2922 | Dice score: 0.5428 | IoU score : 0.4183
